# %%
# # Download 

# pip install -U spacy

# !python -m spacy download en

# %% [markdown]
# # Training data structure for Sapcy
# ```
# dummy_train_data = [
#     ("Uber blew through $1 million a week", [(0, 4, 'ORG')]),
#     ("Android Pay expands to Canada", [(0, 11, 'PRODUCT'), (23, 30, 'GPE')]),
#     ("Spotify steps up Asia expansion", [(0, 8, "ORG"), (17, 21, "LOC")]),
#     ("Google Maps launches location sharing", [(0, 11, "PRODUCT")]),
#     ("Google rebrands its business apps", [(0, 6, "ORG")]),
#     ("look what i found on google! 😂", [(21, 27, "PRODUCT")])]
#
# ```

# %%
import json

# %%
filename = "/home/ubuntu/Grakn/Spacy Play/pubmed_result_abstract-annotated_individual.json"

# %%
# with open(filename, encoding='utf-8') as train_data:
# 	train = json.load(train_data)
    
data = []
with open(filename) as f:
    for line in f:
        data.append(json.loads(line))

# %% [markdown]
# - data is a list containg dictionary of annotated text
# - It is a list of dictionary

# %%
data[0]
# Out:
# {'id': 2,
#  'text': 'The BRAF inhibitor dabrafenib (Tafinlar(Â®)) and the MEK inhibitor trametinib (Mekinist(Â®)) are indicated, as monotherapy or in combination with each other, for the treatment of patients with unresectable or metastatic melanoma with a BRAF (V600) mutation.',
#  'annotations': [{'label': 7, 'start_offset': 4, 'end_offset': 8, 'user': 1},
#   {'label': 8, 'start_offset': 19, 'end_offset': 29, 'user': 1},
#   {'label': 9, 'start_offset': 53, 'end_offset': 56, 'user': 1},
#   {'label': 8, 'start_offset': 67, 'end_offset': 77, 'user': 1},
#   {'label': 10, 'start_offset': 220, 'end_offset': 228, 'user': 1},
#   {'label': 7, 'start_offset': 236, 'end_offset': 240, 'user': 1},
#   {'label': 11, 'start_offset': 242, 'end_offset': 246, 'user': 1}],
#  'meta': {}}

# %%
# Dictionary for label used while annotation


label_dic = {'7':'gene','8':'drug','9':'protien','10':'diesease','11':'varient'}

# %%
# for k,v in label_dic.items():
#     print(k,v)

# %%
# Iterating through all the dictionary of the list of dictionary of annotations

for individual_dictionary in data:
    for dic in individual_dictionary['annotations']:
        # Going to find the label in the dictionary
        temp_key = str(dic['label'])
        #print(label_dic[temp_key])
        dic['label'] = label_dic[temp_key]

# %%
data
# Out:
# [{'id': 2,
#   'text': 'The BRAF inhibitor dabrafenib (Tafinlar(Â®)) and the MEK inhibitor trametinib (Mekinist(Â®)) are indicated, as monotherapy or in combination with each other, for the treatment of patients with unresectable or metastatic melanoma with a BRAF (V600) mutation.',
#   'annotations': [{'label': 'gene',
#     'start_offset': 4,
#     'end_offset': 8,
#     'user': 1},
#    {'label': 'drug', 'start_offset': 19, 'end_offset': 29, 'user': 1},
#    {'label': 'protien', 'start_offset': 53, 'end_offset': 56, 'user': 1},
#    {'label': 'drug', 'start_offset': 67, 'end_offset': 77, 'user': 1},
#    {'label': 'diesease', 'start_offset': 220, 'end_offset': 228, 'user': 1},
#    {'label': 'gene', 'start_offset': 236, 'end_offset': 240, 'user': 1},
#    {'label': 'varient', 'start_offset': 242, 'end_offset': 246, 'user': 1}],
#   'meta': {}},
#  {'id': 4,
#   'text': 'Dabrafenib plus trametinib significantly prolonged progression-free survival (PFS) and overall survival (OS), improved objective response rates (ORRs) and preserved health-related quality of life (HR-QOL) to a greater extent than dabrafenib (in the double-blind COMBI-d study) and vemurafenib (in the open-label COMBI-v study) in two large, randomized, phase III studies in treatment-naÃ¯ve patients with unresectable or metastatic melanoma with BRAF (V600E/K) mutation.',
#   'annotations': [{'label': 'drug',
#     'start_offset': 0,
#     'end_offset': 10,
#     'user': 1},
#    {'label': 'drug', 'start_offset': 16, 'end_offset': 26, 'user': 1},
#    {'label': 'drug', 'start_offset': 230, 'end_offset': 241, 'user': 1},
#    {'label': 'diesease', 'start_offset': 432, 'end_offset': 441, 'user': 1},
#    {'label': 'gene', 'start_offset': 446, 'end_offset': 450, 'user': 1},
#    {'label': 'varient', 'start_offset': 452, 'end_offset': 459, 'user': 1}],
#   'meta': {}},
#  {'id': 5,
#   'text': 'Limited treatment benefit with the combination was also seen in patients who had progressed on prior BRAF inhibitor therapy, as indicated by ORRs of â‰¤ 15Â % and stable disease in â‰¤ 50Â % of patients in small phase I and II studies.Limited treatment benefit with the combination was also seen in patients who had progressed on prior BRAF inhibitor therapy, as indicated by ORRs of â‰¤ 15Â % and stable disease in â‰¤ 50Â % of patients in small phase I and II studies.',
#   'annotations': [{'label': 'gene',
#     'start_offset': 101,
#     'end_offset': 106,
#     'user': 1},
#    {'label': 'gene', 'start_offset': 336, 'end_offset': 341, 'user': 1}],
#   'meta': {}},
#  {'id': 6,
#   'text': 'Combination therapy did not increase overall toxicity relative to dabrafenib or vemurafenib monotherapy, with most adverse events (AEs) mild or moderate in severity and generally manageable.',
#   'annotations': [{'label': 'drug',
#     'start_offset': 66,
#     'end_offset': 77,
#     'user': 1},
#    {'label': 'drug', 'start_offset': 80, 'end_offset': 92, 'user': 1}],
#   'meta': {}},
#  {'id': 9,
#   'text': 'This article reviews the therapeutic efficacy and tolerability of combination treatment with dabrafenib and trametinib in this indication and summarizes relevant pharmacological data.',
#   'annotations': [{'label': 'drug',
#     'start_offset': 93,
#     'end_offset': 104,
#     'user': 1},
#    {'label': 'drug', 'start_offset': 108, 'end_offset': 119, 'user': 1}],
#   'meta': {}},
#  {'id': 10,
#   'text': 'Fewer skin-related AEs (e.g. cutaneous malignancies, hyperkeratinosis and hand-foot syndrome) were reported with combination therapy than with dabrafenib or vemurafenib, probably because of reduced paradoxical activation of the MAPK pathway.',
#   'annotations': [{'label': 'drug',
#     'start_offset': 143,
#     'end_offset': 154,
#     'user': 1},
#    {'label': 'drug', 'start_offset': 157, 'end_offset': 168, 'user': 1}],
#   'meta': {}},
#  {'id': 11,
#   'text': 'Thus, dabrafenib plus trametinib provides an important treatment option for patients with BRAF (V600) mutation-positive unresectable or metastatic melanoma.',
#   'annotations': [{'label': 'drug',
#     'start_offset': 6,
#     'end_offset': 17,
#     'user': 1},
#    {'label': 'drug', 'start_offset': 22, 'end_offset': 33, 'user': 1},
#    {'label': 'gene', 'start_offset': 90, 'end_offset': 95, 'user': 1},
#    {'label': 'varient', 'start_offset': 96, 'end_offset': 100, 'user': 1},
#    {'label': 'diesease', 'start_offset': 147, 'end_offset': 155, 'user': 1}],
#   'meta': {}}]

# %%
# Creating data lsit as per Spacy format
# Iterating through all the dictionary for transforming in spacy data


temp_data= []
for d in data:
    #print(d["text"]) # print text of all dictionary
    #print(d.keys()) # print keys of dictionary
    temp_annotation = d['annotations']
    temp_list = [] # for storing tuples
    temp_data_list = [] # for storing list of tuples
    for label_dic in temp_annotation:
        temp_list.append((label_dic['start_offset'],label_dic['end_offset'],label_dic['label']))
        #emp_list.append()
        #emp_list.append()
        #t(label_dic['start_offset'],label_dic['end_offset'],label_dic['label'])
    temp_data.append((d['text'],{"entities":temp_list}))

# %%
temp_data
# Out:
# [('The BRAF inhibitor dabrafenib (Tafinlar(Â®)) and the MEK inhibitor trametinib (Mekinist(Â®)) are indicated, as monotherapy or in combination with each other, for the treatment of patients with unresectable or metastatic melanoma with a BRAF (V600) mutation.',
#   {'entities': [(4, 8, 'gene'),
#     (19, 29, 'drug'),
#     (53, 56, 'protien'),
#     (67, 77, 'drug'),
#     (220, 228, 'diesease'),
#     (236, 240, 'gene'),
#     (242, 246, 'varient')]}),
#  ('Dabrafenib plus trametinib significantly prolonged progression-free survival (PFS) and overall survival (OS), improved objective response rates (ORRs) and preserved health-related quality of life (HR-QOL) to a greater extent than dabrafenib (in the double-blind COMBI-d study) and vemurafenib (in the open-label COMBI-v study) in two large, randomized, phase III studies in treatment-naÃ¯ve patients with unresectable or metastatic melanoma with BRAF (V600E/K) mutation.',
#   {'entities': [(0, 10, 'drug'),
#     (16, 26, 'drug'),
#     (230, 241, 'drug'),
#     (432, 441, 'diesease'),
#     (446, 450, 'gene'),
#     (452, 459, 'varient')]}),
#  ('Limited treatment benefit with the combination was also seen in patients who had progressed on prior BRAF inhibitor therapy, as indicated by ORRs of â‰¤ 15Â % and stable disease in â‰¤ 50Â % of patients in small phase I and II studies.Limited treatment benefit with the combination was also seen in patients who had progressed on prior BRAF inhibitor therapy, as indicated by ORRs of â‰¤ 15Â % and stable disease in â‰¤ 50Â % of patients in small phase I and II studies.',
#   {'entities': [(101, 106, 'gene'), (336, 341, 'gene')]}),
#  ('Combination therapy did not increase overall toxicity relative to dabrafenib or vemurafenib monotherapy, with most adverse events (AEs) mild or moderate in severity and generally manageable.',
#   {'entities': [(66, 77, 'drug'), (80, 92, 'drug')]}),
#  ('This article reviews the therapeutic efficacy and tolerability of combination treatment with dabrafenib and trametinib in this indication and summarizes relevant pharmacological data.',
#   {'entities': [(93, 104, 'drug'), (108, 119, 'drug')]}),
#  ('Fewer skin-related AEs (e.g. cutaneous malignancies, hyperkeratinosis and hand-foot syndrome) were reported with combination therapy than with dabrafenib or vemurafenib, probably because of reduced paradoxical activation of the MAPK pathway.',
#   {'entities': [(143, 154, 'drug'), (157, 168, 'drug')]}),
#  ('Thus, dabrafenib plus trametinib provides an important treatment option for patients with BRAF (V600) mutation-positive unresectable or metastatic melanoma.',
#   {'entities': [(6, 17, 'drug'),
#     (22, 33, 'drug'),
#     (90, 95, 'gene'),
#     (96, 100, 'varient'),
#     (147, 155, 'diesease')]})]

# %% [markdown]
# ### Preparing training data as per Spacy

# %%
TRAIN_DATA = temp_data

# %%
TRAIN_DATA
# Out:
# [('The BRAF inhibitor dabrafenib (Tafinlar(Â®)) and the MEK inhibitor trametinib (Mekinist(Â®)) are indicated, as monotherapy or in combination with each other, for the treatment of patients with unresectable or metastatic melanoma with a BRAF (V600) mutation.',
#   {'entities': [(4, 8, 'gene'),
#     (19, 29, 'drug'),
#     (53, 56, 'protien'),
#     (67, 77, 'drug'),
#     (220, 228, 'diesease'),
#     (236, 240, 'gene'),
#     (242, 246, 'varient')]}),
#  ('Dabrafenib plus trametinib significantly prolonged progression-free survival (PFS) and overall survival (OS), improved objective response rates (ORRs) and preserved health-related quality of life (HR-QOL) to a greater extent than dabrafenib (in the double-blind COMBI-d study) and vemurafenib (in the open-label COMBI-v study) in two large, randomized, phase III studies in treatment-naÃ¯ve patients with unresectable or metastatic melanoma with BRAF (V600E/K) mutation.',
#   {'entities': [(0, 10, 'drug'),
#     (16, 26, 'drug'),
#     (230, 241, 'drug'),
#     (432, 441, 'diesease'),
#     (446, 450, 'gene'),
#     (452, 459, 'varient')]}),
#  ('Limited treatment benefit with the combination was also seen in patients who had progressed on prior BRAF inhibitor therapy, as indicated by ORRs of â‰¤ 15Â % and stable disease in â‰¤ 50Â % of patients in small phase I and II studies.Limited treatment benefit with the combination was also seen in patients who had progressed on prior BRAF inhibitor therapy, as indicated by ORRs of â‰¤ 15Â % and stable disease in â‰¤ 50Â % of patients in small phase I and II studies.',
#   {'entities': [(101, 106, 'gene'), (336, 341, 'gene')]}),
#  ('Combination therapy did not increase overall toxicity relative to dabrafenib or vemurafenib monotherapy, with most adverse events (AEs) mild or moderate in severity and generally manageable.',
#   {'entities': [(66, 77, 'drug'), (80, 92, 'drug')]}),
#  ('This article reviews the therapeutic efficacy and tolerability of combination treatment with dabrafenib and trametinib in this indication and summarizes relevant pharmacological data.',
#   {'entities': [(93, 104, 'drug'), (108, 119, 'drug')]}),
#  ('Fewer skin-related AEs (e.g. cutaneous malignancies, hyperkeratinosis and hand-foot syndrome) were reported with combination therapy than with dabrafenib or vemurafenib, probably because of reduced paradoxical activation of the MAPK pathway.',
#   {'entities': [(143, 154, 'drug'), (157, 168, 'drug')]}),
#  ('Thus, dabrafenib plus trametinib provides an important treatment option for patients with BRAF (V600) mutation-positive unresectable or metastatic melanoma.',
#   {'entities': [(6, 17, 'drug'),
#     (22, 33, 'drug'),
#     (90, 95, 'gene'),
#     (96, 100, 'varient'),
#     (147, 155, 'diesease')]})]

# %% [markdown]
# #  -- Training Model --

# %%
from __future__ import unicode_literals, print_function

import plac
import random
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding

# %%
path_model_custom = "/home/ubuntu/Grakn/Spacy Play/spacy_en_core_web_lg"

# %%
path_model_custom
# Out:
# '/home/ubuntu/Grakn/Spacy Play/spacy_en_core_web_lg'

# %%
# @plac.annotations(
# model=("en", "option", "m", str),
# output_dir=("Optional output directory", "option", "o", Path),
# n_iter=("5", "option", "n", int)
#     )

# %%
# @plac.annotations(
#     model=("Model name. Defaults to blank 'en' model.", "option", "m", str),
#     new_model_name=("New model name for model meta.", "option", "nm", str),
#     output_dir=("Optional output directory", "option", "o", Path),
#     n_iter=("Number of training iterations", "option", "n", int),)

# %%
def main(model=None, output_dir=None, n_iter=1000):
    """Load the model, set up the pipeline and train the entity recognizer."""
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")

    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")

    # add labels
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # reset and initialize the weights randomly – but only if we're
        # training a new model
        if model is None:
            nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            # batch up the examples using spaCy's minibatch
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,  # dropout - make it harder to memorise data
                    losses=losses,
                )
            print("Losses", losses)

    # test the trained model
    for text, _ in TRAIN_DATA:
        doc = nlp(text)
        print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
        print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

    # save model to output directory
    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

        # test the saved model
        print("Loading from", output_dir)
        nlp2 = spacy.load(output_dir)
        for text, _ in TRAIN_DATA:
            doc = nlp2(text)
            print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
            print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

# %%
if __name__ == "__main__":
    main(model = "en_core_web_lg",output_dir= path_model_custom)
# Out:
# Loaded model 'en_core_web_lg'
# Losses {'ner': 351.10849845409393}
# Losses {'ner': 388.565584897995}
# Losses {'ner': 347.4417562484741}
# Losses {'ner': 331.8790317773819}
# Losses {'ner': 352.67305040359497}
# Losses {'ner': 320.6880597472191}
# Losses {'ner': 345.4755458831787}
# Losses {'ner': 346.2539955377579}
# Losses {'ner': 317.91983294487}
# Losses {'ner': 330.30823731422424}
# Losses {'ner': 299.71725249290466}
# Losses {'ner': 284.6068466901779}
# Losses {'ner': 298.05564427375793}
# Losses {'ner': 296.43757581710815}
# Losses {'ner': 300.38855504989624}
# Losses {'ner': 307.24784541130066}
# Losses {'ner': 286.82343339920044}
# Losses {'ner': 274.07502818107605}
# Losses {'ner': 260.9445958137512}
# Losses {'ner': 297.78058433532715}
# Losses {'ner': 275.33467388153076}
# Losses {'ner': 284.6750916838646}
# Losses {'ner': 281.7085689306259}
# Losses {'ner': 272.0712777376175}
# Losses {'ner': 272.44746148586273}
# Losses {'ner': 260.43229842185974}
# Losses {'ner': 267.4916616678238}
# Losses {'ner': 266.34694027900696}
# Losses {'ner': 301.0447463989258}
# Losses {'ner': 266.41826152801514}
# Losses {'ner': 286.664466381073}
# Losses {'ner': 272.54417872428894}
# Losses {'ner': 288.84376096725464}
# Losses {'ner': 259.39520287513733}
# Losses {'ner': 272.7353265285492}
# Losses {'ner': 289.3734040260315}
# Losses {'ner': 255.3381543159485}
# Losses {'ner': 269.13178730010986}
# Losses {'ner': 260.596192240715}
# Losses {'ner': 273.10447669029236}
# Losses {'ner': 268.2996599674225}
# Losses {'ner': 261.63798332214355}
# Losses {'ner': 267.07644391059875}
# Losses {'ner': 270.57161045074463}
# Losses {'ner': 271.25006890296936}
# Losses {'ner': 266.643146276474}
# Losses {'ner': 291.09550499916077}
# Losses {'ner': 265.040679872036}
# Losses {'ner': 262.79738116264343}
# Losses {'ner': 259.7715172767639}
# Losses {'ner': 252.8828227519989}
# Losses {'ner': 258.5402410030365}
# Losses {'ner': 249.9797396659851}
# Losses {'ner': 267.3889787197113}
# Losses {'ner': 262.82293176651}
# Losses {'ner': 250.860098361969}
# Losses {'ner': 241.6019824743271}
# Losses {'ner': 263.22106862068176}
# Losses {'ner': 245.0732444524765}
# Losses {'ner': 239.95013737678528}
# Losses {'ner': 268.01032972335815}
# Losses {'ner': 242.43794703483582}
# Losses {'ner': 257.08318424224854}
# Losses {'ner': 243.6196712255478}
# Losses {'ner': 248.27758407592773}
# Losses {'ner': 253.51355636119843}
# Losses {'ner': 260.2730462551117}
# Losses {'ner': 252.49681890010834}
# Losses {'ner': 258.9052759408951}
# Losses {'ner': 256.2167854309082}
# Losses {'ner': 248.04207491874695}
# Losses {'ner': 252.22408258914948}
# Losses {'ner': 246.05276131629944}
# Losses {'ner': 254.23356342315674}
# Losses {'ner': 253.41880333423615}
# Losses {'ner': 247.95990109443665}
# Losses {'ner': 243.44134402275085}
# Losses {'ner': 251.78856468200684}
# Losses {'ner': 264.80216643214226}
# Losses {'ner': 251.05107271671295}
# Losses {'ner': 244.2574384212494}
# Losses {'ner': 253.9089698791504}
# Losses {'ner': 260.78633081912994}
# Losses {'ner': 242.03559637069702}
# Losses {'ner': 253.5729856491089}
# Losses {'ner': 249.27516198158264}
# Losses {'ner': 256.4872636795044}
# Losses {'ner': 259.0110731124878}
# Losses {'ner': 250.96792662143707}
# Losses {'ner': 259.86155247688293}
# Losses {'ner': 258.902321100235}
# Losses {'ner': 244.30454754829407}
# Losses {'ner': 240.68974089622498}
# Losses {'ner': 242.9562051296234}
# Losses {'ner': 246.94941800832748}
# Losses {'ner': 251.24092841148376}
# Losses {'ner': 250.98434615135193}
# Losses {'ner': 250.3318145275116}
# Losses {'ner': 257.80034482479095}
# Losses {'ner': 252.2353571653366}
# Losses {'ner': 243.62421041727066}
# Losses {'ner': 236.03328132629395}
# Losses {'ner': 252.35795843601227}
# Losses {'ner': 247.05872237682343}
# Losses {'ner': 251.6349766254425}
# Losses {'ner': 244.66817665100098}
# Losses {'ner': 250.7888435125351}
# Losses {'ner': 231.18045365810394}
# Losses {'ner': 244.45131301879883}
# Losses {'ner': 247.90811705589294}
# Losses {'ner': 229.09687852859497}
# Losses {'ner': 244.35624623298645}
# Losses {'ner': 262.6579910516739}
# Losses {'ner': 251.08382487297058}
# Losses {'ner': 251.11936116218567}
# Losses {'ner': 239.00441813468933}
# Losses {'ner': 240.92825531959534}
# Losses {'ner': 256.7052392959595}
# Losses {'ner': 226.4341198205948}
# Losses {'ner': 252.78174448013306}
# Losses {'ner': 241.5910371541977}
# Losses {'ner': 240.26030945777893}
# Losses {'ner': 250.19630867242813}
# Losses {'ner': 237.45089602470398}
# Losses {'ner': 254.7498803138733}
# Losses {'ner': 244.13677334785461}
# Losses {'ner': 252.1931664943695}
# Losses {'ner': 249.91896557807922}
# Losses {'ner': 243.14377903938293}
# Losses {'ner': 246.39439070224762}
# Losses {'ner': 237.93176865577698}
# Losses {'ner': 240.56062245368958}
# Losses {'ner': 236.70585894584656}
# Losses {'ner': 238.049094080925}
# Losses {'ner': 259.788689494133}
# Losses {'ner': 233.80747628211975}
# Losses {'ner': 242.98405689001083}
# Losses {'ner': 248.36528325080872}
# Losses {'ner': 248.30304503440857}
# Losses {'ner': 244.1240187883377}
# Losses {'ner': 250.7458953857422}
# Losses {'ner': 242.20729160308838}
# Losses {'ner': 249.63269352912903}
# Losses {'ner': 250.17612886428833}
# Losses {'ner': 243.04559004306793}
# Losses {'ner': 229.48291024565697}
# Losses {'ner': 241.0949625968933}
# Losses {'ner': 233.02057480812073}
# Losses {'ner': 233.82934057712555}
# Losses {'ner': 225.80043411254883}
# Losses {'ner': 237.31512594223022}
# Losses {'ner': 230.65840196609497}
# Losses {'ner': 244.7888150215149}
# Losses {'ner': 246.54975032806396}
# Losses {'ner': 254.46129047870636}
# Losses {'ner': 235.91242861747742}
# Losses {'ner': 234.84024167060852}
# Losses {'ner': 241.46039295196533}
# Losses {'ner': 242.15761375427246}
# Losses {'ner': 240.94945192337036}
# Losses {'ner': 253.25329566001892}
# Losses {'ner': 238.33684188127518}
# Losses {'ner': 245.03205633163452}
# Losses {'ner': 238.1612800359726}
# Losses {'ner': 250.8303918838501}
# Losses {'ner': 248.11632251739502}
# Losses {'ner': 229.98072504997253}
# Losses {'ner': 221.68017053604126}
# Losses {'ner': 235.5959117412567}
# Losses {'ner': 244.00410318374634}
# Losses {'ner': 230.950585603714}
# Losses {'ner': 247.8761613368988}
# Losses {'ner': 233.05747365951538}
# Losses {'ner': 240.85335683822632}
# Losses {'ner': 247.3069224357605}
# Losses {'ner': 241.67041969299316}
# Losses {'ner': 237.52977967262268}
# Losses {'ner': 247.29099082946777}
# Losses {'ner': 243.43687999248505}
# Losses {'ner': 239.35908031463623}
# Losses {'ner': 234.52209496498108}
# Losses {'ner': 231.49410045146942}
# Losses {'ner': 239.50333654880524}
# Losses {'ner': 232.3284431695938}
# Losses {'ner': 239.14097833633423}
# Losses {'ner': 241.65515226125717}
# Losses {'ner': 233.4107882976532}
# Losses {'ner': 240.85810565948486}
# Losses {'ner': 243.59119033813477}
# Losses {'ner': 245.3553370833397}
# Losses {'ner': 240.38884449005127}
# Losses {'ner': 246.35944628715515}
# Losses {'ner': 240.72322392463684}
# Losses {'ner': 232.57397508621216}
# Losses {'ner': 236.9492472410202}
# Losses {'ner': 240.7534475326538}
# Losses {'ner': 244.46789121627808}
# Losses {'ner': 239.98352003097534}
# Losses {'ner': 242.3748073577881}
# Losses {'ner': 236.77786791324615}
# Losses {'ner': 240.89625573158264}
# Losses {'ner': 235.41416317224503}
# Losses {'ner': 242.3837662935257}
# Losses {'ner': 247.19479632377625}
# Losses {'ner': 241.96106386184692}
# Losses {'ner': 226.8866810798645}
# Losses {'ner': 241.53404808044434}
# Losses {'ner': 242.9791224002838}
# Losses {'ner': 244.04319429397583}
# Losses {'ner': 232.57610154151917}
# Losses {'ner': 232.78224289417267}
# Losses {'ner': 241.46750390529633}
# Losses {'ner': 250.3661060333252}
# Losses {'ner': 240.72015273571014}
# Losses {'ner': 236.82265067100525}
# Losses {'ner': 217.07106828689575}
# Losses {'ner': 230.2342039346695}
# Losses {'ner': 242.81835794448853}
# Losses {'ner': 233.6255248785019}
# Losses {'ner': 241.9578139781952}
# Losses {'ner': 231.26910972595215}
# Losses {'ner': 227.05696040391922}
# Losses {'ner': 228.66403436660767}
# Losses {'ner': 241.57196414470673}
# Losses {'ner': 237.31072568893433}
# Losses {'ner': 237.27237284183502}
# Losses {'ner': 245.4099566936493}
# Losses {'ner': 247.4124300479889}
# Losses {'ner': 236.29479885101318}
# Losses {'ner': 238.19594383239746}
# Losses {'ner': 232.86639094352722}
# Losses {'ner': 228.9029312133789}
# Losses {'ner': 247.06744462251663}
# Losses {'ner': 245.5352246761322}
# Losses {'ner': 236.39042735099792}
# Losses {'ner': 246.87600684165955}
# Losses {'ner': 251.09105467796326}
# Losses {'ner': 233.6366627216339}
# Losses {'ner': 235.8771733045578}
# Losses {'ner': 221.96025329828262}
# Losses {'ner': 227.77365100383759}
# Losses {'ner': 230.28813433647156}
# Losses {'ner': 224.94705414772034}
# Losses {'ner': 256.2351031303406}
# Losses {'ner': 240.87209904193878}
# Losses {'ner': 254.76977908611298}
# Losses {'ner': 246.39050960540771}
# Losses {'ner': 243.85203969478607}
# Losses {'ner': 234.20369482040405}
# Losses {'ner': 230.91706705093384}
# Losses {'ner': 230.25865185260773}
# Losses {'ner': 240.6725445985794}
# Losses {'ner': 224.6598494052887}
# Losses {'ner': 231.51966953277588}
# Losses {'ner': 246.90274953842163}
# Losses {'ner': 232.99806886911392}
# Losses {'ner': 231.121839761734}
# Losses {'ner': 234.4996476173401}
# Losses {'ner': 230.86529922485352}
# Losses {'ner': 239.97690451145172}
# Losses {'ner': 231.09726428985596}
# Losses {'ner': 234.0229851603508}
# Losses {'ner': 242.33097195625305}
# Losses {'ner': 239.91440272331238}
# Losses {'ner': 240.11331939697266}
# Losses {'ner': 244.03682577610016}
# Losses {'ner': 241.21195769309998}
# Losses {'ner': 232.4873025417328}
# Losses {'ner': 238.53507113456726}
# Losses {'ner': 226.0170982480049}
# Losses {'ner': 224.1049718260765}
# Losses {'ner': 219.3982012271881}
# Losses {'ner': 227.8427391052246}
# Losses {'ner': 236.35972547531128}
# Losses {'ner': 226.52055096626282}
# Losses {'ner': 239.67364692687988}
# Losses {'ner': 234.48469507694244}
# Losses {'ner': 233.9701339006424}
# Losses {'ner': 233.29974365234375}
# Losses {'ner': 243.35298788547516}
# Losses {'ner': 237.4665197134018}
# Losses {'ner': 238.834627866745}
# Losses {'ner': 231.95517754554749}
# Losses {'ner': 236.37009239196777}
# Losses {'ner': 251.84419465065002}
# Losses {'ner': 229.45359659194946}
# Losses {'ner': 233.55554962158203}
# Losses {'ner': 240.14527714252472}
# Losses {'ner': 224.9765067100525}
# Losses {'ner': 233.9547589868307}
# Losses {'ner': 247.68487334251404}
# Losses {'ner': 243.76189160346985}
# Losses {'ner': 224.14297938346863}
# Losses {'ner': 230.1812343597412}
# Losses {'ner': 236.9798126220703}
# Losses {'ner': 232.50518095493317}
# Losses {'ner': 234.1200371980667}
# Losses {'ner': 216.03526306152344}
# Losses {'ner': 231.75966180860996}
# Losses {'ner': 244.5027916431427}
# Losses {'ner': 240.9880690574646}
# Losses {'ner': 222.9988068342209}
# Losses {'ner': 236.31207919120789}
# Losses {'ner': 235.84850239753723}
# Losses {'ner': 244.05627846717834}
# Losses {'ner': 251.15494298934937}
# Losses {'ner': 233.9399664402008}
# Losses {'ner': 239.610675573349}
# Losses {'ner': 228.4536918401718}
# Losses {'ner': 238.59856033325195}
# Losses {'ner': 239.53534626960754}
# Losses {'ner': 223.936105966568}
# Losses {'ner': 236.24115753173828}
# Losses {'ner': 227.4807825088501}
# Losses {'ner': 241.3072350025177}
# Losses {'ner': 233.21117520332336}
# Losses {'ner': 248.31842064857483}
# Losses {'ner': 243.95403242111206}
# Losses {'ner': 236.11946594715118}
# Losses {'ner': 250.62886881828308}
# Losses {'ner': 237.78873616456985}
# Losses {'ner': 233.22273802757263}
# Losses {'ner': 228.69819927215576}
# Losses {'ner': 237.09377336502075}
# Losses {'ner': 237.33975517749786}
# Losses {'ner': 233.8224309682846}
# Losses {'ner': 230.3493001461029}
# Losses {'ner': 229.8147071003914}
# Losses {'ner': 254.62864768505096}
# Losses {'ner': 241.56528639793396}
# Losses {'ner': 220.25677287578583}
# Losses {'ner': 226.246741771698}
# Losses {'ner': 226.1831818819046}
# Losses {'ner': 235.3731918334961}
# Losses {'ner': 216.71386981010437}
# Losses {'ner': 249.60384058952332}
# Losses {'ner': 236.88661789894104}
# Losses {'ner': 247.50324189662933}
# Losses {'ner': 231.90006923675537}
# Losses {'ner': 239.6462733745575}
# Losses {'ner': 230.12218856811523}
# Losses {'ner': 245.54376077651978}
# Losses {'ner': 226.0217044353485}
# Losses {'ner': 231.9499695301056}
# Losses {'ner': 247.01179957389832}
# Losses {'ner': 228.28574228286743}
# Losses {'ner': 220.6819007396698}
# Losses {'ner': 235.91805934906006}
# Losses {'ner': 244.04237604141235}
# Losses {'ner': 225.50314044952393}
# Losses {'ner': 226.98916172981262}
# Losses {'ner': 241.94583189487457}
# Losses {'ner': 232.36570417881012}
# Losses {'ner': 239.91035401821136}
# Losses {'ner': 230.77001953125}
# Losses {'ner': 253.84757924079895}
# Losses {'ner': 234.78328597545624}
# Losses {'ner': 236.35221815109253}
# Losses {'ner': 239.32206672430038}
# Losses {'ner': 235.32421255111694}
# Losses {'ner': 235.34339880943298}
# Losses {'ner': 228.27819991111755}
# Losses {'ner': 236.9393446445465}
# Losses {'ner': 238.64708185195923}
# Losses {'ner': 232.57940113544464}
# Losses {'ner': 227.71037888526917}
# Losses {'ner': 240.5723011493683}
# Losses {'ner': 234.56759977340698}
# Losses {'ner': 226.37988138198853}
# Losses {'ner': 222.89900398254395}
# Losses {'ner': 237.60993933677673}
# Losses {'ner': 241.70588731765747}
# Losses {'ner': 245.76040744781494}
# Losses {'ner': 228.54488170146942}
# Losses {'ner': 228.3243373632431}
# Losses {'ner': 220.84474778175354}
# Losses {'ner': 244.08528804779053}
# Losses {'ner': 240.1474391222}
# Losses {'ner': 221.11735606193542}
# Losses {'ner': 234.44419634342194}
# Losses {'ner': 239.7900459766388}
# Losses {'ner': 237.33865690231323}
# Losses {'ner': 234.74978256225586}
# Losses {'ner': 229.35316395759583}
# Losses {'ner': 227.92600905895233}
# Losses {'ner': 238.16227102279663}
# Losses {'ner': 229.7946012020111}
# Losses {'ner': 231.68246495723724}
# Losses {'ner': 231.81660848855972}
# Losses {'ner': 225.300430893898}
# Losses {'ner': 238.3484046459198}
# Losses {'ner': 224.24907517433167}
# Losses {'ner': 230.6500644683838}
# Losses {'ner': 233.42420530319214}
# Losses {'ner': 235.55183684825897}
# Losses {'ner': 235.93273282051086}
# Losses {'ner': 238.24618291854858}
# Losses {'ner': 228.43344068527222}
# Losses {'ner': 222.3228656053543}
# Losses {'ner': 232.0071771144867}
# Losses {'ner': 235.47277069091797}
# Losses {'ner': 225.63306510448456}
# Losses {'ner': 237.53270936012268}
# Losses {'ner': 237.6215214729309}
# Losses {'ner': 234.35657501220703}
# Losses {'ner': 231.4015622138977}
# Losses {'ner': 227.35610628128052}
# Losses {'ner': 218.95799565315247}
# Losses {'ner': 238.55650305747986}
# Losses {'ner': 236.85231113433838}
# Losses {'ner': 230.98352766036987}
# Losses {'ner': 235.45287036895752}
# Losses {'ner': 218.37250208854675}
# Losses {'ner': 237.86408853530884}
# Losses {'ner': 237.8549473285675}
# Losses {'ner': 233.66789257526398}
# Losses {'ner': 237.5775966644287}
# Losses {'ner': 238.60709083080292}
# Losses {'ner': 242.5357825756073}
# Losses {'ner': 231.6301145553589}
# Losses {'ner': 226.95177745819092}
# Losses {'ner': 225.68374061584473}
# Losses {'ner': 237.6118335723877}
# Losses {'ner': 243.0496146082878}
# Losses {'ner': 224.0696929693222}
# Losses {'ner': 247.89892446994781}
# Losses {'ner': 230.5277419090271}
# Losses {'ner': 228.1725155711174}
# Losses {'ner': 235.41434240341187}
# Losses {'ner': 233.82428884506226}
# Losses {'ner': 233.06393837928772}
# Losses {'ner': 224.9031046628952}
# Losses {'ner': 221.02138304710388}
# Losses {'ner': 232.52153980731964}
# Losses {'ner': 228.4177747964859}
# Losses {'ner': 236.2888526916504}
# Losses {'ner': 223.74837911128998}
# Losses {'ner': 222.1071457862854}
# Losses {'ner': 222.69920992851257}
# Losses {'ner': 241.59051881730556}
# Losses {'ner': 214.85926949977875}
# Losses {'ner': 226.05049538612366}
# Losses {'ner': 234.83548855781555}
# Losses {'ner': 229.40283739566803}
# Losses {'ner': 229.6191577911377}
# Losses {'ner': 242.01049423217773}
# Losses {'ner': 215.6742568090558}
# Losses {'ner': 235.73826432228088}
# Losses {'ner': 237.49150079488754}
# Losses {'ner': 230.48982548713684}
# Losses {'ner': 252.83140790462494}
# Losses {'ner': 232.23471009731293}
# Losses {'ner': 225.3821575641632}
# Losses {'ner': 233.16683411598206}
# Losses {'ner': 235.1311366558075}
# Losses {'ner': 235.23406565189362}
# Losses {'ner': 220.26603746414185}
# Losses {'ner': 232.5239770412445}
# Losses {'ner': 231.51955366134644}
# Losses {'ner': 233.92973911762238}
# Losses {'ner': 222.23240447044373}
# Losses {'ner': 234.75236028432846}
# Losses {'ner': 235.03328347206116}
# Losses {'ner': 244.24441742897034}
# Losses {'ner': 230.94468069076538}
# Losses {'ner': 227.66441702842712}
# Losses {'ner': 223.17853391170502}
# Losses {'ner': 238.4419800043106}
# Losses {'ner': 223.55610513687134}
# Losses {'ner': 232.8647530078888}
# Losses {'ner': 230.54333984851837}
# Losses {'ner': 238.4959671497345}
# Losses {'ner': 230.9300286769867}
# Losses {'ner': 238.188232421875}
# Losses {'ner': 232.59092843532562}
# Losses {'ner': 217.31947553157806}
# Losses {'ner': 226.26286268234253}
# Losses {'ner': 239.99363887310028}
# Losses {'ner': 235.0160572528839}
# Losses {'ner': 233.71570873260498}
# Losses {'ner': 219.91142201423645}
# Losses {'ner': 233.9765277504921}
# Losses {'ner': 239.34053707122803}
# Losses {'ner': 220.54632222652435}
# Losses {'ner': 232.84493350982666}
# Losses {'ner': 241.22601437568665}
# Losses {'ner': 239.0030117034912}
# Losses {'ner': 229.91782879829407}
# Losses {'ner': 229.58780145645142}
# Losses {'ner': 227.85076141357422}
# Losses {'ner': 250.0526304244995}
# Losses {'ner': 231.4900209903717}
# Losses {'ner': 226.82943320274353}
# Losses {'ner': 228.06738567352295}
# Losses {'ner': 226.17665362358093}
# Losses {'ner': 246.86148929595947}
# Losses {'ner': 224.99926924705505}
# Losses {'ner': 229.31083691120148}
# Losses {'ner': 232.47655057907104}
# Losses {'ner': 242.5118328332901}
# Losses {'ner': 215.92603611946106}
# Losses {'ner': 225.43117141723633}
# Losses {'ner': 225.2126805782318}
# Losses {'ner': 231.40691661834717}
# Losses {'ner': 240.40659356117249}
# Losses {'ner': 227.1015031337738}
# Losses {'ner': 213.54374241828918}
# Losses {'ner': 241.2693793773651}
# Losses {'ner': 219.48833191394806}
# Losses {'ner': 234.48637008666992}
# Losses {'ner': 231.2047734260559}
# Losses {'ner': 221.18342900276184}
# Losses {'ner': 236.5946090221405}
# Losses {'ner': 234.7660105228424}
# Losses {'ner': 227.63172352313995}
# Losses {'ner': 226.79068732261658}
# Losses {'ner': 234.65489852428436}
# Losses {'ner': 236.0026547908783}
# Losses {'ner': 232.23536324501038}
# Losses {'ner': 238.6355823278427}
# Losses {'ner': 236.89193177223206}
# Losses {'ner': 237.09793257713318}
# Losses {'ner': 221.38135480880737}
# Losses {'ner': 227.10850954055786}
# Losses {'ner': 227.50972217321396}
# Losses {'ner': 235.43993723392487}
# Losses {'ner': 227.8540482521057}
# Losses {'ner': 221.64669287204742}
# Losses {'ner': 234.58693957328796}
# Losses {'ner': 228.29034316539764}
# Losses {'ner': 219.91360986232758}
# Losses {'ner': 234.18029880523682}
# Losses {'ner': 229.18190574645996}
# Losses {'ner': 234.2949140071869}
# Losses {'ner': 235.5141246318817}
# Losses {'ner': 232.94136595726013}
# Losses {'ner': 234.60469675064087}
# Losses {'ner': 235.4009280204773}
# Losses {'ner': 243.31314170360565}
# Losses {'ner': 239.68124496936798}
# Losses {'ner': 226.67416095733643}
# Losses {'ner': 215.09606647491455}
# Losses {'ner': 226.88817512989044}
# Losses {'ner': 218.1072827577591}
# Losses {'ner': 230.53020524978638}
# Losses {'ner': 225.17447018623352}
# Losses {'ner': 237.39911425113678}
# Losses {'ner': 234.58020734786987}
# Losses {'ner': 236.8982805609703}
# Losses {'ner': 216.89029705524445}
# Losses {'ner': 234.03006744384766}
# Losses {'ner': 237.3463146686554}
# Losses {'ner': 227.54864990711212}
# Losses {'ner': 236.82855224609375}
# Losses {'ner': 232.5555636882782}
# Losses {'ner': 224.5311814546585}
# Losses {'ner': 222.25943183898926}
# Losses {'ner': 231.87919878959656}
# Losses {'ner': 226.0765198469162}
# Losses {'ner': 239.04764699935913}
# Losses {'ner': 229.89751505851746}
# Losses {'ner': 231.74445497989655}
# Losses {'ner': 230.40880799293518}
# Losses {'ner': 233.59008359909058}
# Losses {'ner': 230.15752410888672}
# Losses {'ner': 237.85227584838867}
# Losses {'ner': 224.2988116145134}
# Losses {'ner': 231.84819388389587}
# Losses {'ner': 231.74053120613098}
# Losses {'ner': 216.5359125137329}
# Losses {'ner': 217.26924526691437}
# Losses {'ner': 236.49304008483887}
# Losses {'ner': 233.7075707912445}
# Losses {'ner': 234.63729310035706}
# Losses {'ner': 229.5271577835083}
# Losses {'ner': 221.6455557346344}
# Losses {'ner': 235.09732103347778}
# Losses {'ner': 217.55693876743317}
# Losses {'ner': 234.90364861488342}
# Losses {'ner': 236.2039337158203}
# Losses {'ner': 234.40767002105713}
# Losses {'ner': 222.32072949409485}
# Losses {'ner': 230.72283136844635}
# Losses {'ner': 218.98447799682617}
# Losses {'ner': 238.13388288021088}
# Losses {'ner': 233.61290550231934}
# Losses {'ner': 227.88202214241028}
# Losses {'ner': 248.70359861850739}
# Losses {'ner': 223.13816499710083}
# Losses {'ner': 215.87724328041077}
# Losses {'ner': 225.1511161327362}
# Losses {'ner': 216.57358050346375}
# Losses {'ner': 241.6015658378601}
# Losses {'ner': 238.63917636871338}
# Losses {'ner': 227.3639042377472}
# Losses {'ner': 231.43074941635132}
# Losses {'ner': 225.51078486442566}
# Losses {'ner': 238.1449192762375}
# Losses {'ner': 234.42111492156982}
# Losses {'ner': 233.9919891357422}
# Losses {'ner': 236.63592326641083}
# Losses {'ner': 211.21504986286163}
# Losses {'ner': 234.89239716529846}
# Losses {'ner': 223.96294569969177}
# Losses {'ner': 235.80484628677368}
# Losses {'ner': 236.2138932943344}
# Losses {'ner': 218.86517214775085}
# Losses {'ner': 230.74796617031097}
# Losses {'ner': 228.10111784934998}
# Losses {'ner': 226.7437286376953}
# Losses {'ner': 237.3081170320511}
# Losses {'ner': 217.31546258926392}
# Losses {'ner': 237.3634955883026}
# Losses {'ner': 217.67489099502563}
# Losses {'ner': 227.7922933101654}
# Losses {'ner': 224.97795367240906}
# Losses {'ner': 229.9430320262909}
# Losses {'ner': 224.35942387580872}
# Losses {'ner': 230.95757365226746}
# Losses {'ner': 228.07740533351898}
# Losses {'ner': 231.7992353439331}
# Losses {'ner': 231.58376002311707}
# Losses {'ner': 233.5836580991745}
# Losses {'ner': 228.2115854024887}
# Losses {'ner': 242.09370493888855}
# Losses {'ner': 226.3155393600464}
# Losses {'ner': 222.33852088451385}
# Losses {'ner': 237.6827701330185}
# Losses {'ner': 231.55309599637985}
# Losses {'ner': 233.67928266525269}
# Losses {'ner': 234.35350632667542}
# Losses {'ner': 233.3773124217987}
# Losses {'ner': 225.47093772888184}
# Losses {'ner': 221.79010581970215}
# Losses {'ner': 223.13822412490845}
# Losses {'ner': 240.67302656173706}
# Losses {'ner': 227.9901578426361}
# Losses {'ner': 229.59358632564545}
# Losses {'ner': 224.39101207256317}
# Losses {'ner': 228.89546728134155}
# Losses {'ner': 223.9524827003479}
# Losses {'ner': 221.14220345020294}
# Losses {'ner': 229.37087213993073}
# Losses {'ner': 233.39276504516602}
# Losses {'ner': 237.23294925689697}
# Losses {'ner': 223.62021780014038}
# Losses {'ner': 226.58376336097717}
# Losses {'ner': 225.9006745815277}
# Losses {'ner': 234.25578093528748}
# Losses {'ner': 237.88928651809692}
# Losses {'ner': 231.38085532188416}
# Losses {'ner': 223.93113100528717}
# Losses {'ner': 248.51014590263367}
# Losses {'ner': 218.55119466781616}
# Losses {'ner': 229.5038961172104}
# Losses {'ner': 236.03359937667847}
# Losses {'ner': 229.0502588748932}
# Losses {'ner': 234.62123346328735}
# Losses {'ner': 236.66094374656677}
# Losses {'ner': 226.90976405143738}
# Losses {'ner': 223.493337392807}
# Losses {'ner': 229.21567630767822}
# Losses {'ner': 228.15833687782288}
# Losses {'ner': 217.09241795539856}
# Losses {'ner': 225.71932125091553}
# Losses {'ner': 238.2604718208313}
# Losses {'ner': 225.27829432487488}
# Losses {'ner': 224.71515198796988}
# Losses {'ner': 229.57903718948364}
# Losses {'ner': 224.12082636356354}
# Losses {'ner': 244.55849647521973}
# Losses {'ner': 233.4465652704239}
# Losses {'ner': 237.04866993427277}
# Losses {'ner': 225.20777773857117}
# Losses {'ner': 218.6595811843872}
# Losses {'ner': 214.62854647636414}
# Losses {'ner': 234.52183496952057}
# Losses {'ner': 233.35893654823303}
# Losses {'ner': 235.29499399662018}
# Losses {'ner': 231.7948021888733}
# Losses {'ner': 232.2324149608612}
# Losses {'ner': 226.1449375152588}
# Losses {'ner': 226.11666226387024}
# Losses {'ner': 230.88155317306519}
# Losses {'ner': 224.9408210515976}
# Losses {'ner': 230.9451940059662}
# Losses {'ner': 235.58747386932373}
# Losses {'ner': 217.73581719398499}
# Losses {'ner': 236.52205228805542}
# Losses {'ner': 226.08472073078156}
# Losses {'ner': 223.89594331383705}
# Losses {'ner': 231.8710902929306}
# Losses {'ner': 216.70196044445038}
# Losses {'ner': 233.6622064113617}
# Losses {'ner': 238.3745230436325}
# Losses {'ner': 223.1033480167389}
# Losses {'ner': 228.89955615997314}
# Losses {'ner': 232.4482103586197}
# Losses {'ner': 236.06813645362854}
# Losses {'ner': 232.55451142787933}
# Losses {'ner': 233.69624876976013}
# Losses {'ner': 230.44201970100403}
# Losses {'ner': 231.04834055900574}
# Losses {'ner': 229.97133994102478}
# Losses {'ner': 221.86905765533447}
# Losses {'ner': 229.2554633617401}
# Losses {'ner': 240.98541963100433}
# Losses {'ner': 234.9305818080902}
# Losses {'ner': 232.8790955543518}
# Losses {'ner': 229.56696224212646}
# Losses {'ner': 227.92602157592773}
# Losses {'ner': 224.13146996498108}
# Losses {'ner': 220.96911785006523}
# Losses {'ner': 232.46591973304749}
# Losses {'ner': 230.39528489112854}
# Losses {'ner': 239.91586256027222}
# Losses {'ner': 215.36139976978302}
# Losses {'ner': 226.99625062942505}
# Losses {'ner': 209.43849098682404}
# Losses {'ner': 230.13026082515717}
# Losses {'ner': 234.90162420272827}
# Losses {'ner': 229.4929929971695}
# Losses {'ner': 223.6851178407669}
# Losses {'ner': 237.4086912870407}
# Losses {'ner': 229.431795835495}
# Losses {'ner': 211.58354938030243}
# Losses {'ner': 215.9823590517044}
# Losses {'ner': 229.30610036849976}
# Losses {'ner': 230.9776200056076}
# Losses {'ner': 216.90763974189758}
# Losses {'ner': 227.31260538101196}
# Losses {'ner': 234.77997744083405}
# Losses {'ner': 237.55975449085236}
# Losses {'ner': 234.50929725170135}
# Losses {'ner': 221.85109400749207}
# Losses {'ner': 224.89296460151672}
# Losses {'ner': 223.93422985076904}
# Losses {'ner': 211.18497240543365}
# Losses {'ner': 222.4240279197693}
# Losses {'ner': 226.46822142601013}
# Losses {'ner': 225.44879019260406}
# Losses {'ner': 240.6982342004776}
# Losses {'ner': 238.85251569747925}
# Losses {'ner': 237.99100863933563}
# Losses {'ner': 235.6786448955536}
# Losses {'ner': 232.9965853691101}
# Losses {'ner': 226.77588325738907}
# Losses {'ner': 232.36004996299744}
# Losses {'ner': 226.19184970855713}
# Losses {'ner': 237.7822036743164}
# Losses {'ner': 230.52898144721985}
# Losses {'ner': 237.67559027671814}
# Losses {'ner': 229.93893337249756}
# Losses {'ner': 223.53183138370514}
# Losses {'ner': 208.7192347049713}
# Losses {'ner': 232.86458587646484}
# Losses {'ner': 229.60163807868958}
# Losses {'ner': 231.56785464286804}
# Losses {'ner': 234.00230276584625}
# Losses {'ner': 223.64738988876343}
# Losses {'ner': 228.71665585041046}
# Losses {'ner': 222.11167645454407}
# Losses {'ner': 229.27680087089539}
# Losses {'ner': 210.9689575433731}
# Losses {'ner': 224.4649374485016}
# Losses {'ner': 232.87370102107525}
# Losses {'ner': 233.90943598747253}
# Losses {'ner': 231.50684332847595}
# Losses {'ner': 224.89854383468628}
# Losses {'ner': 224.40969157218933}
# Losses {'ner': 220.48676586151123}
# Losses {'ner': 235.27369856834412}
# Losses {'ner': 231.23966598510742}
# Losses {'ner': 234.72202920913696}
# Losses {'ner': 230.59614849090576}
# Losses {'ner': 230.1569800376892}
# Losses {'ner': 226.98285055160522}
# Losses {'ner': 228.36933517456055}
# Losses {'ner': 231.01565584540367}
# Losses {'ner': 228.85593235492706}
# Losses {'ner': 224.14859741926193}
# Losses {'ner': 229.16187143325806}
# Losses {'ner': 225.91441416740417}
# Losses {'ner': 226.0213302373886}
# Losses {'ner': 227.45566248893738}
# Losses {'ner': 218.63451766967773}
# Losses {'ner': 215.26559591293335}
# Losses {'ner': 226.41759848594666}
# Losses {'ner': 222.29867315292358}
# Losses {'ner': 243.78914880752563}
# Losses {'ner': 227.5419843196869}
# Losses {'ner': 232.45325589179993}
# Losses {'ner': 233.64155220985413}
# Losses {'ner': 233.3603162765503}
# Losses {'ner': 225.9168300628662}
# Losses {'ner': 236.82016468048096}
# Losses {'ner': 225.07151436805725}
# Losses {'ner': 229.70201495289803}
# Losses {'ner': 226.63987386226654}
# Losses {'ner': 222.69924867153168}
# Losses {'ner': 230.73102259635925}
# Losses {'ner': 232.3481261730194}
# Losses {'ner': 229.3800469636917}
# Losses {'ner': 219.12453854084015}
# Losses {'ner': 231.24807608127594}
# Losses {'ner': 233.93626141548157}
# Losses {'ner': 219.45159459114075}
# Losses {'ner': 228.87919116020203}
# Losses {'ner': 223.44668292999268}
# Losses {'ner': 229.26880931854248}
# Losses {'ner': 231.58620953559875}
# Losses {'ner': 223.7191026210785}
# Losses {'ner': 234.2499098777771}
# Losses {'ner': 225.4614658355713}
# Losses {'ner': 217.52817797660828}
# Losses {'ner': 232.8793728351593}
# Losses {'ner': 227.45351779460907}
# Losses {'ner': 234.547833442688}
# Losses {'ner': 220.64992207288742}
# Losses {'ner': 239.966583609581}
# Losses {'ner': 236.5518925189972}
# Losses {'ner': 238.6587507724762}
# Losses {'ner': 232.4783272743225}
# Losses {'ner': 227.34736359119415}
# Losses {'ner': 235.2827763557434}
# Losses {'ner': 226.27241492271423}
# Losses {'ner': 228.91973233222961}
# Losses {'ner': 232.01823544502258}
# Losses {'ner': 224.2271659374237}
# Losses {'ner': 208.54896140098572}
# Losses {'ner': 223.7236944437027}
# Losses {'ner': 224.7783329486847}
# Losses {'ner': 220.51283288002014}
# Losses {'ner': 223.03267407417297}
# Losses {'ner': 233.58041763305664}
# Losses {'ner': 231.34884524345398}
# Losses {'ner': 227.8282654285431}
# Losses {'ner': 227.05568480491638}
# Losses {'ner': 217.87379240989685}
# Losses {'ner': 222.25895404815674}
# Losses {'ner': 236.41646814346313}
# Losses {'ner': 221.34965300559998}
# Losses {'ner': 236.71640157699585}
# Losses {'ner': 220.13518571853638}
# Losses {'ner': 229.48753023147583}
# Losses {'ner': 233.19265937805176}
# Losses {'ner': 234.54015231132507}
# Losses {'ner': 216.3504101037979}
# Losses {'ner': 227.49508237838745}
# Losses {'ner': 240.63237345218658}
# Losses {'ner': 228.24108064174652}
# Losses {'ner': 232.74596762657166}
# Losses {'ner': 221.0195118188858}
# Losses {'ner': 237.09399795532227}
# Losses {'ner': 224.28032612800598}
# Losses {'ner': 216.26869708299637}
# Losses {'ner': 230.9298621416092}
# Losses {'ner': 224.96734142303467}
# Losses {'ner': 223.8146106004715}
# Losses {'ner': 233.416574716568}
# Losses {'ner': 221.9500002861023}
# Losses {'ner': 227.29307651519775}
# Losses {'ner': 224.0288872718811}
# Losses {'ner': 230.72652006149292}
# Losses {'ner': 228.92047929763794}
# Losses {'ner': 213.1594681739807}
# Losses {'ner': 234.4955713748932}
# Losses {'ner': 225.87651872634888}
# Losses {'ner': 222.4767639040947}
# Losses {'ner': 232.28774440288544}
# Losses {'ner': 230.8722470998764}
# Losses {'ner': 221.45314979553223}
# Losses {'ner': 230.52624666690826}
# Losses {'ner': 218.195174574852}
# Losses {'ner': 239.1206043958664}
# Losses {'ner': 236.3581805229187}
# Losses {'ner': 226.244567155838}
# Losses {'ner': 225.13387191295624}
# Losses {'ner': 210.75983095169067}
# Losses {'ner': 231.93500542640686}
# Losses {'ner': 230.4928616285324}
# Losses {'ner': 227.72228860855103}
# Losses {'ner': 221.92693865299225}
# Losses {'ner': 234.16641700267792}
# Losses {'ner': 249.36118745803833}
# Losses {'ner': 230.52097177505493}
# Losses {'ner': 216.77793192863464}
# Losses {'ner': 230.6042823791504}
# Losses {'ner': 228.78093093633652}
# Losses {'ner': 227.43251538276672}
# Losses {'ner': 227.84365510940552}
# Losses {'ner': 234.81271767616272}
# Losses {'ner': 227.77856707572937}
# Losses {'ner': 230.72031593322754}
# Losses {'ner': 237.3574719429016}
# Losses {'ner': 219.16194415092468}
# Losses {'ner': 229.94487714767456}
# Losses {'ner': 224.3306361436844}
# Losses {'ner': 232.26850819587708}
# Losses {'ner': 226.52392578125}
# Losses {'ner': 219.31021630764008}
# Losses {'ner': 215.64060711860657}
# Losses {'ner': 221.93046498298645}
# Losses {'ner': 237.1225483417511}
# Losses {'ner': 224.36424803733826}
# Losses {'ner': 224.87571120262146}
# Losses {'ner': 227.26101458072662}
# Losses {'ner': 237.51490139961243}
# Losses {'ner': 223.04349267482758}
# Losses {'ner': 232.6588089466095}
# Losses {'ner': 227.2632040977478}
# Losses {'ner': 225.77198100090027}
# Losses {'ner': 224.48818063735962}
# Losses {'ner': 242.72327399253845}
# Losses {'ner': 226.542142868042}
# Losses {'ner': 250.46701216697693}
# Losses {'ner': 223.81351006031036}
# Losses {'ner': 222.42789328098297}
# Losses {'ner': 239.20377254486084}
# Losses {'ner': 223.12618494033813}
# Losses {'ner': 209.17692458629608}
# Losses {'ner': 235.48058891296387}
# Losses {'ner': 235.27759885787964}
# Losses {'ner': 234.33424925804138}
# Losses {'ner': 207.434427857399}
# Losses {'ner': 231.40548181533813}
# Losses {'ner': 224.5379746556282}
# Losses {'ner': 225.29167795181274}
# Losses {'ner': 218.6088489294052}
# Losses {'ner': 232.96180391311646}
# Losses {'ner': 217.6973408460617}
# Losses {'ner': 237.40986514091492}
# Losses {'ner': 237.85097694396973}
# Losses {'ner': 234.4577980041504}
# Losses {'ner': 233.52131247520447}
# Losses {'ner': 226.20929515361786}
# Losses {'ner': 226.89863109588623}
# Losses {'ner': 225.6846297979355}
# Losses {'ner': 235.78747868537903}
# Losses {'ner': 228.72855710983276}
# Losses {'ner': 227.70942783355713}
# Losses {'ner': 232.33290541172028}
# Losses {'ner': 229.0754474401474}
# Losses {'ner': 216.3827407360077}
# Losses {'ner': 226.98310089111328}
# Losses {'ner': 218.71267223358154}
# Losses {'ner': 231.55864918231964}
# Losses {'ner': 231.79143393039703}
# Losses {'ner': 228.9815456867218}
# Losses {'ner': 221.76495361328125}
# Losses {'ner': 213.6664823293686}
# Losses {'ner': 228.01917600631714}
# Losses {'ner': 233.87990760803223}
# Losses {'ner': 234.4457609653473}
# Losses {'ner': 224.98776930570602}
# Losses {'ner': 214.5377995222807}
# Losses {'ner': 219.07737922668457}
# Losses {'ner': 218.5037897825241}
# Losses {'ner': 236.6707468032837}
# Losses {'ner': 227.2183063030243}
# Losses {'ner': 236.67265820503235}
# Losses {'ner': 244.32980036735535}
# Losses {'ner': 217.8340916633606}
# Losses {'ner': 224.1265513896942}
# Losses {'ner': 233.15836381912231}
# Losses {'ner': 222.23577427864075}
# Losses {'ner': 224.4675942659378}
# Losses {'ner': 217.7204041481018}
# Losses {'ner': 227.89754927158356}
# Losses {'ner': 216.13045293092728}
# Losses {'ner': 222.94964230060577}
# Losses {'ner': 231.70309925079346}
# Losses {'ner': 238.57020592689514}
# Losses {'ner': 229.8649287223816}
# Losses {'ner': 230.99213552474976}
# Losses {'ner': 234.4040083885193}
# Losses {'ner': 217.2306990623474}
# Losses {'ner': 215.80235528945923}
# Losses {'ner': 221.53398323059082}
# Losses {'ner': 223.19354033470154}
# Losses {'ner': 232.94142985343933}
# Losses {'ner': 232.65285778045654}
# Losses {'ner': 231.87804400920868}
# Losses {'ner': 221.33642834424973}
# Losses {'ner': 213.01274275779724}
# Losses {'ner': 234.5610272884369}
# Losses {'ner': 233.2490028142929}
# Losses {'ner': 230.20053911209106}
# Losses {'ner': 229.10562372207642}
# Losses {'ner': 237.27087926864624}
# Losses {'ner': 218.433180809021}
# Losses {'ner': 217.4446861743927}
# Losses {'ner': 228.8969805240631}
# Losses {'ner': 225.5678101181984}
# Losses {'ner': 231.2676156759262}
# Losses {'ner': 215.37510681152344}
# Losses {'ner': 217.24105668067932}
# Losses {'ner': 221.01626074314117}
# Losses {'ner': 229.05526506900787}
# Losses {'ner': 229.07695531845093}
# Entities [('trametinib', 'drug')]
# Tokens [('This', '', 2), ('article', '', 2), ('reviews', '', 2), ('the', '', 2), ('therapeutic', '', 2), ('efficacy', '', 2), ('and', '', 2), ('tolerability', '', 2), ('of', '', 2), ('combination', '', 2), ('treatment', '', 2), ('with', '', 2), ('dabrafenib', '', 2), ('and', '', 2), ('trametinib', 'drug', 3), ('in', '', 2), ('this', '', 2), ('indication', '', 2), ('and', '', 2), ('summarizes', '', 2), ('relevant', '', 2), ('pharmacological', '', 2), ('data', '', 2), ('.', '', 2)]
# Entities [('BRAF', 'gene'), ('dabrafenib', 'drug'), ('MEK', 'protien'), ('trametinib', 'drug'), ('melanoma', 'diesease'), ('BRAF', 'gene'), ('V600', 'varient')]
# Tokens [('The', '', 2), ('BRAF', 'gene', 3), ('inhibitor', '', 2), ('dabrafenib', 'drug', 3), ('(', '', 2), ('Tafinlar(Â', '', 2), ('®', '', 2), (')', '', 2), (')', '', 2), ('and', '', 2), ('the', '', 2), ('MEK', 'protien', 3), ('inhibitor', '', 2), ('trametinib', 'drug', 3), ('(', '', 2), ('Mekinist(Â', '', 2), ('®', '', 2), (')', '', 2), (')', '', 2), ('are', '', 2), ('indicated', '', 2), (',', '', 2), ('as', '', 2), ('monotherapy', '', 2), ('or', '', 2), ('in', '', 2), ('combination', '', 2), ('with', '', 2), ('each', '', 2), ('other', '', 2), (',', '', 2), ('for', '', 2), ('the', '', 2), ('treatment', '', 2), ('of', '', 2), ('patients', '', 2), ('with', '', 2), ('unresectable', '', 2), ('or', '', 2), ('metastatic', '', 2), ('melanoma', 'diesease', 3), ('with', '', 2), ('a', '', 2), ('BRAF', 'gene', 3), ('(', '', 2), ('V600', 'varient', 3), (')', '', 2), ('mutation', '', 2), ('.', '', 2)]
# Entities [('trametinib', 'drug'), ('BRAF', 'gene'), ('V600', 'varient'), ('melanoma', 'diesease')]
# Tokens [('Thus', '', 2), (',', '', 2), ('dabrafenib', '', 2), ('plus', '', 2), ('trametinib', 'drug', 3), ('provides', '', 2), ('an', '', 2), ('important', '', 2), ('treatment', '', 2), ('option', '', 2), ('for', '', 2), ('patients', '', 2), ('with', '', 2), ('BRAF', 'gene', 3), ('(', '', 2), ('V600', 'varient', 3), (')', '', 2), ('mutation', '', 2), ('-', '', 2), ('positive', '', 2), ('unresectable', '', 2), ('or', '', 2), ('metastatic', '', 2), ('melanoma', 'diesease', 3), ('.', '', 2)]
# Entities [('vemurafenib', 'drug')]
# Tokens [('Combination', '', 2), ('therapy', '', 2), ('did', '', 2), ('not', '', 2), ('increase', '', 2), ('overall', '', 2), ('toxicity', '', 2), ('relative', '', 2), ('to', '', 2), ('dabrafenib', '', 2), ('or', '', 2), ('vemurafenib', 'drug', 3), ('monotherapy', '', 2), (',', '', 2), ('with', '', 2), ('most', '', 2), ('adverse', '', 2), ('events', '', 2), ('(', '', 2), ('AEs', '', 2), (')', '', 2), ('mild', '', 2), ('or', '', 2), ('moderate', '', 2), ('in', '', 2), ('severity', '', 2), ('and', '', 2), ('generally', '', 2), ('manageable', '', 2), ('.', '', 2)]
# Entities [('Dabrafenib', 'drug'), ('trametinib', 'drug'), ('melanoma', 'diesease'), ('BRAF', 'gene'), ('V600E/K', 'varient')]
# Tokens [('Dabrafenib', 'drug', 3), ('plus', '', 2), ('trametinib', 'drug', 3), ('significantly', '', 2), ('prolonged', '', 2), ('progression', '', 2), ('-', '', 2), ('free', '', 2), ('survival', '', 2), ('(', '', 2), ('PFS', '', 2), (')', '', 2), ('and', '', 2), ('overall', '', 2), ('survival', '', 2), ('(', '', 2), ('OS', '', 2), (')', '', 2), (',', '', 2), ('improved', '', 2), ('objective', '', 2), ('response', '', 2), ('rates', '', 2), ('(', '', 2), ('ORRs', '', 2), (')', '', 2), ('and', '', 2), ('preserved', '', 2), ('health', '', 2), ('-', '', 2), ('related', '', 2), ('quality', '', 2), ('of', '', 2), ('life', '', 2), ('(', '', 2), ('HR', '', 2), ('-', '', 2), ('QOL', '', 2), (')', '', 2), ('to', '', 2), ('a', '', 2), ('greater', '', 2), ('extent', '', 2), ('than', '', 2), ('dabrafenib', '', 2), ('(', '', 2), ('in', '', 2), ('the', '', 2), ('double', '', 2), ('-', '', 2), ('blind', '', 2), ('COMBI', '', 2), ('-', '', 2), ('d', '', 2), ('study', '', 2), (')', '', 2), ('and', '', 2), ('vemurafenib', '', 2), ('(', '', 2), ('in', '', 2), ('the', '', 2), ('open', '', 2), ('-', '', 2), ('label', '', 2), ('COMBI', '', 2), ('-', '', 2), ('v', '', 2), ('study', '', 2), (')', '', 2), ('in', '', 2), ('two', '', 2), ('large', '', 2), (',', '', 2), ('randomized', '', 2), (',', '', 2), ('phase', '', 2), ('III', '', 2), ('studies', '', 2), ('in', '', 2), ('treatment', '', 2), ('-', '', 2), ('naÃ¯ve', '', 2), ('patients', '', 2), ('with', '', 2), ('unresectable', '', 2), ('or', '', 2), ('metastatic', '', 2), ('melanoma', 'diesease', 3), ('with', '', 2), ('BRAF', 'gene', 3), ('(', '', 2), ('V600E', 'varient', 3), ('/', 'varient', 1), ('K', 'varient', 1), (')', '', 2), ('mutation', '', 2), ('.', '', 2)]
# Entities [('BRAF', 'gene')]
# Tokens [('Limited', '', 2), ('treatment', '', 2), ('benefit', '', 2), ('with', '', 2), ('the', '', 2), ('combination', '', 2), ('was', '', 2), ('also', '', 2), ('seen', '', 2), ('in', '', 2), ('patients', '', 2), ('who', '', 2), ('had', '', 2), ('progressed', '', 2), ('on', '', 2), ('prior', '', 2), ('BRAF', 'gene', 3), ('inhibitor', '', 2), ('therapy', '', 2), (',', '', 2), ('as', '', 2), ('indicated', '', 2), ('by', '', 2), ('ORRs', '', 2), ('of', '', 2), ('â‰¤', '', 2), ('15Â', '', 2), ('%', '', 2), ('and', '', 2), ('stable', '', 2), ('disease', '', 2), ('in', '', 2), ('â‰¤', '', 2), ('50Â', '', 2), ('%', '', 2), ('of', '', 2), ('patients', '', 2), ('in', '', 2), ('small', '', 2), ('phase', '', 2), ('I', '', 2), ('and', '', 2), ('II', '', 2), ('studies', '', 2), ('.', '', 2), ('Limited', '', 2), ('treatment', '', 2), ('benefit', '', 2), ('with', '', 2), ('the', '', 2), ('combination', '', 2), ('was', '', 2), ('also', '', 2), ('seen', '', 2), ('in', '', 2), ('patients', '', 2), ('who', '', 2), ('had', '', 2), ('progressed', '', 2), ('on', '', 2), ('prior', '', 2), ('BRAF', '', 2), ('inhibitor', '', 2), ('therapy', '', 2), (',', '', 2), ('as', '', 2), ('indicated', '', 2), ('by', '', 2), ('ORRs', '', 2), ('of', '', 2), ('â‰¤', '', 2), ('15Â', '', 2), ('%', '', 2), ('and', '', 2), ('stable', '', 2), ('disease', '', 2), ('in', '', 2), ('â‰¤', '', 2), ('50Â', '', 2), ('%', '', 2), ('of', '', 2), ('patients', '', 2), ('in', '', 2), ('small', '', 2), ('phase', '', 2), ('I', '', 2), ('and', '', 2), ('II', '', 2), ('studies', '', 2), ('.', '', 2)]
# Entities [('vemurafenib', 'drug')]
# Tokens [('Fewer', '', 2), ('skin', '', 2), ('-', '', 2), ('related', '', 2), ('AEs', '', 2), ('(', '', 2), ('e.g.', '', 2), ('cutaneous', '', 2), ('malignancies', '', 2), (',', '', 2), ('hyperkeratinosis', '', 2), ('and', '', 2), ('hand', '', 2), ('-', '', 2), ('foot', '', 2), ('syndrome', '', 2), (')', '', 2), ('were', '', 2), ('reported', '', 2), ('with', '', 2), ('combination', '', 2), ('therapy', '', 2), ('than', '', 2), ('with', '', 2), ('dabrafenib', '', 2), ('or', '', 2), ('vemurafenib', 'drug', 3), (',', '', 2), ('probably', '', 2), ('because', '', 2), ('of', '', 2), ('reduced', '', 2), ('paradoxical', '', 2), ('activation', '', 2), ('of', '', 2), ('the', '', 2), ('MAPK', '', 2), ('pathway', '', 2), ('.', '', 2)]
# Saved model to /home/ubuntu/Grakn/Spacy Play/spacy_en_core_web_lg
# Loading from /home/ubuntu/Grakn/Spacy Play/spacy_en_core_web_lg
# Entities [('trametinib', 'drug')]
# Tokens [('This', '', 2), ('article', '', 2), ('reviews', '', 2), ('the', '', 2), ('therapeutic', '', 2), ('efficacy', '', 2), ('and', '', 2), ('tolerability', '', 2), ('of', '', 2), ('combination', '', 2), ('treatment', '', 2), ('with', '', 2), ('dabrafenib', '', 2), ('and', '', 2), ('trametinib', 'drug', 3), ('in', '', 2), ('this', '', 2), ('indication', '', 2), ('and', '', 2), ('summarizes', '', 2), ('relevant', '', 2), ('pharmacological', '', 2), ('data', '', 2), ('.', '', 2)]
# Entities [('BRAF', 'gene'), ('dabrafenib', 'drug'), ('MEK', 'protien'), ('trametinib', 'drug'), ('melanoma', 'diesease'), ('BRAF', 'gene'), ('V600', 'varient')]
# Tokens [('The', '', 2), ('BRAF', 'gene', 3), ('inhibitor', '', 2), ('dabrafenib', 'drug', 3), ('(', '', 2), ('Tafinlar(Â', '', 2), ('®', '', 2), (')', '', 2), (')', '', 2), ('and', '', 2), ('the', '', 2), ('MEK', 'protien', 3), ('inhibitor', '', 2), ('trametinib', 'drug', 3), ('(', '', 2), ('Mekinist(Â', '', 2), ('®', '', 2), (')', '', 2), (')', '', 2), ('are', '', 2), ('indicated', '', 2), (',', '', 2), ('as', '', 2), ('monotherapy', '', 2), ('or', '', 2), ('in', '', 2), ('combination', '', 2), ('with', '', 2), ('each', '', 2), ('other', '', 2), (',', '', 2), ('for', '', 2), ('the', '', 2), ('treatment', '', 2), ('of', '', 2), ('patients', '', 2), ('with', '', 2), ('unresectable', '', 2), ('or', '', 2), ('metastatic', '', 2), ('melanoma', 'diesease', 3), ('with', '', 2), ('a', '', 2), ('BRAF', 'gene', 3), ('(', '', 2), ('V600', 'varient', 3), (')', '', 2), ('mutation', '', 2), ('.', '', 2)]
# Entities [('trametinib', 'drug'), ('BRAF', 'gene'), ('V600', 'varient'), ('melanoma', 'diesease')]
# Tokens [('Thus', '', 2), (',', '', 2), ('dabrafenib', '', 2), ('plus', '', 2), ('trametinib', 'drug', 3), ('provides', '', 2), ('an', '', 2), ('important', '', 2), ('treatment', '', 2), ('option', '', 2), ('for', '', 2), ('patients', '', 2), ('with', '', 2), ('BRAF', 'gene', 3), ('(', '', 2), ('V600', 'varient', 3), (')', '', 2), ('mutation', '', 2), ('-', '', 2), ('positive', '', 2), ('unresectable', '', 2), ('or', '', 2), ('metastatic', '', 2), ('melanoma', 'diesease', 3), ('.', '', 2)]
# Entities [('vemurafenib', 'drug')]
# Tokens [('Combination', '', 2), ('therapy', '', 2), ('did', '', 2), ('not', '', 2), ('increase', '', 2), ('overall', '', 2), ('toxicity', '', 2), ('relative', '', 2), ('to', '', 2), ('dabrafenib', '', 2), ('or', '', 2), ('vemurafenib', 'drug', 3), ('monotherapy', '', 2), (',', '', 2), ('with', '', 2), ('most', '', 2), ('adverse', '', 2), ('events', '', 2), ('(', '', 2), ('AEs', '', 2), (')', '', 2), ('mild', '', 2), ('or', '', 2), ('moderate', '', 2), ('in', '', 2), ('severity', '', 2), ('and', '', 2), ('generally', '', 2), ('manageable', '', 2), ('.', '', 2)]
# Entities [('Dabrafenib', 'drug'), ('trametinib', 'drug'), ('melanoma', 'diesease'), ('BRAF', 'gene'), ('V600E/K', 'varient')]
# Tokens [('Dabrafenib', 'drug', 3), ('plus', '', 2), ('trametinib', 'drug', 3), ('significantly', '', 2), ('prolonged', '', 2), ('progression', '', 2), ('-', '', 2), ('free', '', 2), ('survival', '', 2), ('(', '', 2), ('PFS', '', 2), (')', '', 2), ('and', '', 2), ('overall', '', 2), ('survival', '', 2), ('(', '', 2), ('OS', '', 2), (')', '', 2), (',', '', 2), ('improved', '', 2), ('objective', '', 2), ('response', '', 2), ('rates', '', 2), ('(', '', 2), ('ORRs', '', 2), (')', '', 2), ('and', '', 2), ('preserved', '', 2), ('health', '', 2), ('-', '', 2), ('related', '', 2), ('quality', '', 2), ('of', '', 2), ('life', '', 2), ('(', '', 2), ('HR', '', 2), ('-', '', 2), ('QOL', '', 2), (')', '', 2), ('to', '', 2), ('a', '', 2), ('greater', '', 2), ('extent', '', 2), ('than', '', 2), ('dabrafenib', '', 2), ('(', '', 2), ('in', '', 2), ('the', '', 2), ('double', '', 2), ('-', '', 2), ('blind', '', 2), ('COMBI', '', 2), ('-', '', 2), ('d', '', 2), ('study', '', 2), (')', '', 2), ('and', '', 2), ('vemurafenib', '', 2), ('(', '', 2), ('in', '', 2), ('the', '', 2), ('open', '', 2), ('-', '', 2), ('label', '', 2), ('COMBI', '', 2), ('-', '', 2), ('v', '', 2), ('study', '', 2), (')', '', 2), ('in', '', 2), ('two', '', 2), ('large', '', 2), (',', '', 2), ('randomized', '', 2), (',', '', 2), ('phase', '', 2), ('III', '', 2), ('studies', '', 2), ('in', '', 2), ('treatment', '', 2), ('-', '', 2), ('naÃ¯ve', '', 2), ('patients', '', 2), ('with', '', 2), ('unresectable', '', 2), ('or', '', 2), ('metastatic', '', 2), ('melanoma', 'diesease', 3), ('with', '', 2), ('BRAF', 'gene', 3), ('(', '', 2), ('V600E', 'varient', 3), ('/', 'varient', 1), ('K', 'varient', 1), (')', '', 2), ('mutation', '', 2), ('.', '', 2)]
# Entities [('BRAF', 'gene')]
# Tokens [('Limited', '', 2), ('treatment', '', 2), ('benefit', '', 2), ('with', '', 2), ('the', '', 2), ('combination', '', 2), ('was', '', 2), ('also', '', 2), ('seen', '', 2), ('in', '', 2), ('patients', '', 2), ('who', '', 2), ('had', '', 2), ('progressed', '', 2), ('on', '', 2), ('prior', '', 2), ('BRAF', 'gene', 3), ('inhibitor', '', 2), ('therapy', '', 2), (',', '', 2), ('as', '', 2), ('indicated', '', 2), ('by', '', 2), ('ORRs', '', 2), ('of', '', 2), ('â‰¤', '', 2), ('15Â', '', 2), ('%', '', 2), ('and', '', 2), ('stable', '', 2), ('disease', '', 2), ('in', '', 2), ('â‰¤', '', 2), ('50Â', '', 2), ('%', '', 2), ('of', '', 2), ('patients', '', 2), ('in', '', 2), ('small', '', 2), ('phase', '', 2), ('I', '', 2), ('and', '', 2), ('II', '', 2), ('studies', '', 2), ('.', '', 2), ('Limited', '', 2), ('treatment', '', 2), ('benefit', '', 2), ('with', '', 2), ('the', '', 2), ('combination', '', 2), ('was', '', 2), ('also', '', 2), ('seen', '', 2), ('in', '', 2), ('patients', '', 2), ('who', '', 2), ('had', '', 2), ('progressed', '', 2), ('on', '', 2), ('prior', '', 2), ('BRAF', '', 2), ('inhibitor', '', 2), ('therapy', '', 2), (',', '', 2), ('as', '', 2), ('indicated', '', 2), ('by', '', 2), ('ORRs', '', 2), ('of', '', 2), ('â‰¤', '', 2), ('15Â', '', 2), ('%', '', 2), ('and', '', 2), ('stable', '', 2), ('disease', '', 2), ('in', '', 2), ('â‰¤', '', 2), ('50Â', '', 2), ('%', '', 2), ('of', '', 2), ('patients', '', 2), ('in', '', 2), ('small', '', 2), ('phase', '', 2), ('I', '', 2), ('and', '', 2), ('II', '', 2), ('studies', '', 2), ('.', '', 2)]
# Entities [('vemurafenib', 'drug')]
# Tokens [('Fewer', '', 2), ('skin', '', 2), ('-', '', 2), ('related', '', 2), ('AEs', '', 2), ('(', '', 2), ('e.g.', '', 2), ('cutaneous', '', 2), ('malignancies', '', 2), (',', '', 2), ('hyperkeratinosis', '', 2), ('and', '', 2), ('hand', '', 2), ('-', '', 2), ('foot', '', 2), ('syndrome', '', 2), (')', '', 2), ('were', '', 2), ('reported', '', 2), ('with', '', 2), ('combination', '', 2), ('therapy', '', 2), ('than', '', 2), ('with', '', 2), ('dabrafenib', '', 2), ('or', '', 2), ('vemurafenib', 'drug', 3), (',', '', 2), ('probably', '', 2), ('because', '', 2), ('of', '', 2), ('reduced', '', 2), ('paradoxical', '', 2), ('activation', '', 2), ('of', '', 2), ('the', '', 2), ('MAPK', '', 2), ('pathway', '', 2), ('.', '', 2)]

# %% [markdown]
# # NER

# %%
test_doc = 'The BRAF inhibitor dabrafenib (Tafinlar(Â®)) and the MEK inhibitor trametinib (Mekinist(Â®)) are indicated, as monotherapy or in combination with each other, for the treatment of patients with unresectable or metastatic melanoma with a BRAF (V600) mutation. This article reviews the therapeutic efficacy and tolerability of combination treatment with dabrafenib and trametinib in this indication and summarizes relevant pharmacological data. Dabrafenib plus trametinib significantly prolonged progression-free survival (PFS) and overall survival (OS), improved objective response rates (ORRs) and preserved health-related quality of life (HR-QOL) to a greater extent than dabrafenib (in the double-blind COMBI-d study) and vemurafenib (in the open-label COMBI-v study) in two large, randomized, phase III studies in treatment-naÃ¯ve patients with unresectable or metastatic melanoma with BRAF (V600E/K) mutation. Limited treatment benefit with the combination was also seen in patients who had progressed on prior BRAF inhibitor therapy, as indicated by ORRs of â‰¤ 15Â\xa0% and stable disease in â‰¤ 50Â\xa0% of patients in small phase I and II studies. Combination therapy did not increase overall toxicity relative to dabrafenib or vemurafenib monotherapy, with most adverse events (AEs) mild or moderate in severity and generally manageable. Fewer skin-related AEs (e.g. cutaneous malignancies, hyperkeratinosis and hand-foot syndrome) were reported with combination therapy than with dabrafenib or vemurafenib, probably because of reduced paradoxical activation of the MAPK pathway. Thus, dabrafenib plus trametinib provides an important treatment option for patients with BRAF (V600) mutation-positive unresectable or metastatic melanoma.'

# %%
#nlp = spacy.load("en_core_web_lg")
#doc = nlp(u"Apple is looking at buying U.K. startup for $1 billion")

nlp = spacy.load("/home/ubuntu/Grakn/Spacy Play/spacy_en_core_web_lg")
doc1 = nlp(test_doc)



# for ent in doc.ents:
#     print(ent.text, ent.start_char, ent.end_char, ent.label_)

for ent in doc1.ents:
    print(ent.text,"-->",ent.label_)
# Out:
# BRAF --> gene
# dabrafenib --> drug
# MEK --> protien
# trametinib --> drug
# melanoma --> diesease
# BRAF --> gene
# V600 --> varient
# trametinib --> drug
# Dabrafenib --> drug
# trametinib --> drug
# melanoma --> diesease
# BRAF --> gene
# V600E/K --> varient
# vemurafenib --> drug
# vemurafenib --> drug
# trametinib --> drug
# BRAF --> gene
# V600 --> varient
# melanoma --> diesease

# %% [markdown]
# # Playing with Spacy Model

# %%
doc ='''The BRAF inhibitor dabrafenib (Tafinlar(Â®)) and the MEK inhibitor trametinib (Mekinist(Â®)) are indicated, as monotherapy or in combination with each other, for the treatment of patients with unresectable or metastatic melanoma with a BRAF (V600) mutation. 
This article reviews the therapeutic efficacy and tolerability of combination treatment with dabrafenib and trametinib in this indication and summarizes relevant pharmacological data. 
Dabrafenib plus trametinib significantly prolonged progression-free survival (PFS) and overall survival (OS), improved objective response rates (ORRs) and preserved health-related quality of life (HR-QOL) to a greater extent than dabrafenib (in the double-blind COMBI-d study) and vemurafenib (in the open-label COMBI-v study) in two large, randomized, phase III studies in treatment-naÃ¯ve patients with unresectable or metastatic melanoma with BRAF (V600E/K) mutation. Limited treatment benefit with the combination was also seen in patients who had progressed on prior BRAF inhibitor therapy, as indicated by ORRs of â‰¤ 15Â % and stable disease in â‰¤ 50Â % of patients in small phase I and II studies. Combination therapy did not increase overall toxicity relative to dabrafenib or vemurafenib monotherapy, with most adverse events (AEs) mild or moderate in severity and generally manageable. Fewer skin-related AEs (e.g. cutaneous malignancies, hyperkeratinosis and hand-foot syndrome) were reported with combination therapy than with dabrafenib or vemurafenib, probably because of reduced paradoxical activation of the MAPK pathway. Thus, dabrafenib plus trametinib provides an important treatment option for patients with BRAF (V600) mutation-positive unresectable or metastatic melanoma.
'''

# %%
doc1 = '''Hi, my name is Tobias. I’m a trained mathematician that now works as a data scientist and machine learning engineer. In 2018 I achieved the status of a kaggle master and still spend quite some time there.'''

# %%
# Loading spacy model
# In this case, trained model is being loaded
nlp = spacy.load("/home/ubuntu/Grakn/Spacy Play/spacy_en_core_web_lg")#("en_core_web_sm")

# %%
# Parsing document to spacy loaded model
nlp_doc = nlp(doc)

# %%
# POS tagging
print('#---- POS Tagging ----#''\n')
for token in nlp_doc:
    print(token.text,"-->", token.lemma_,"-->", token.pos_,"-->", token.tag_,"-->", token.dep_,"-->",
            token.shape_,"-->", token.is_alpha,"-->", token.is_stop)

# Dependency Parsing
print('\n'"#---- Dependency Parsing ----#"'\n')
for chunk in nlp_doc.noun_chunks:
    print(chunk.text,"-->", chunk.root.text,"-->", chunk.root.dep_,"-->",
            chunk.root.head.text)
    
# Entity Extration
print('\n'"#---- Entity using Spacy ----#"'\n')
for ent in nlp_doc.ents:
    print(ent.text,"-->",ent.label_)
# Out:
# #---- POS Tagging ----#
#
# The --> the --> DET --> DT --> det --> Xxx --> True --> True
# BRAF --> BRAF --> PROPN --> NNP --> compound --> XXXX --> True --> False
# inhibitor --> inhibitor --> NOUN --> NN --> compound --> xxxx --> True --> False
# dabrafenib --> dabrafenib --> NOUN --> NN --> nsubjpass --> xxxx --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# Tafinlar(Â --> Tafinlar(Â --> PROPN --> NNP --> compound --> Xxxxx(X --> False --> False
# ® --> ® --> PROPN --> NNP --> appos --> ® --> False --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# the --> the --> DET --> DT --> det --> xxx --> True --> True
# MEK --> MEK --> PROPN --> NNP --> compound --> XXX --> True --> False
# inhibitor --> inhibitor --> NOUN --> NN --> compound --> xxxx --> True --> False
# trametinib --> trametinib --> NOUN --> NN --> conj --> xxxx --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# Mekinist(Â --> Mekinist(Â --> PROPN --> NNP --> compound --> Xxxxx(X --> False --> False
# ® --> ® --> PROPN --> NNP --> appos --> ® --> False --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# are --> be --> VERB --> VBP --> auxpass --> xxx --> True --> True
# indicated --> indicate --> VERB --> VBN --> ROOT --> xxxx --> True --> False
# , --> , --> PUNCT --> , --> punct --> , --> False --> False
# as --> as --> ADP --> IN --> advmod --> xx --> True --> True
# monotherapy --> monotherapy --> ADV --> RB --> advmod --> xxxx --> True --> False
# or --> or --> CCONJ --> CC --> cc --> xx --> True --> True
# in --> in --> ADP --> IN --> advcl --> xx --> True --> True
# combination --> combination --> NOUN --> NN --> pobj --> xxxx --> True --> False
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# each --> each --> DET --> DT --> det --> xxxx --> True --> True
# other --> other --> ADJ --> JJ --> pobj --> xxxx --> True --> True
# , --> , --> PUNCT --> , --> punct --> , --> False --> False
# for --> for --> ADP --> IN --> conj --> xxx --> True --> True
# the --> the --> DET --> DT --> det --> xxx --> True --> True
# treatment --> treatment --> NOUN --> NN --> pobj --> xxxx --> True --> False
# of --> of --> ADP --> IN --> prep --> xx --> True --> True
# patients --> patient --> NOUN --> NNS --> pobj --> xxxx --> True --> False
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# unresectable --> unresectable --> ADJ --> JJ --> amod --> xxxx --> True --> False
# or --> or --> CCONJ --> CC --> cc --> xx --> True --> True
# metastatic --> metastatic --> ADJ --> JJ --> conj --> xxxx --> True --> False
# melanoma --> melanoma --> NOUN --> NN --> pobj --> xxxx --> True --> False
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# a --> a --> DET --> DT --> det --> x --> True --> True
# BRAF --> BRAF --> PROPN --> NNP --> nmod --> XXXX --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# V600 --> V600 --> PROPN --> NNP --> subtok --> Xddd --> False --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# mutation --> mutation --> NOUN --> NN --> pobj --> xxxx --> True --> False
# . --> . --> PUNCT --> . --> punct --> . --> False --> False
#
#  -->
#  --> SPACE --> _SP -->  -->
#  --> False --> False
# This --> this --> DET --> DT --> det --> Xxxx --> True --> True
# article --> article --> NOUN --> NN --> nsubj --> xxxx --> True --> False
# reviews --> review --> VERB --> VBZ --> ROOT --> xxxx --> True --> False
# the --> the --> DET --> DT --> det --> xxx --> True --> True
# therapeutic --> therapeutic --> ADJ --> JJ --> amod --> xxxx --> True --> False
# efficacy --> efficacy --> NOUN --> NN --> dobj --> xxxx --> True --> False
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# tolerability --> tolerability --> NOUN --> NN --> conj --> xxxx --> True --> False
# of --> of --> ADP --> IN --> prep --> xx --> True --> True
# combination --> combination --> NOUN --> NN --> compound --> xxxx --> True --> False
# treatment --> treatment --> NOUN --> NN --> pobj --> xxxx --> True --> False
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# dabrafenib --> dabrafenib --> NOUN --> NN --> pobj --> xxxx --> True --> False
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# trametinib --> trametinib --> NOUN --> NN --> conj --> xxxx --> True --> False
# in --> in --> ADP --> IN --> prep --> xx --> True --> True
# this --> this --> DET --> DT --> det --> xxxx --> True --> True
# indication --> indication --> NOUN --> NN --> pobj --> xxxx --> True --> False
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# summarizes --> summarize --> VERB --> VBZ --> conj --> xxxx --> True --> False
# relevant --> relevant --> ADJ --> JJ --> amod --> xxxx --> True --> False
# pharmacological --> pharmacological --> ADJ --> JJ --> amod --> xxxx --> True --> False
# data --> datum --> NOUN --> NNS --> dobj --> xxxx --> True --> False
# . --> . --> PUNCT --> . --> punct --> . --> False --> False
#
#  -->
#  --> SPACE --> _SP -->  -->
#  --> False --> False
# Dabrafenib --> Dabrafenib --> PROPN --> NNP --> nsubj --> Xxxxx --> True --> False
# plus --> plus --> CCONJ --> CC --> cc --> xxxx --> True --> False
# trametinib --> trametinib --> NOUN --> NN --> conj --> xxxx --> True --> False
# significantly --> significantly --> ADV --> RB --> advmod --> xxxx --> True --> False
# prolonged --> prolong --> VERB --> VBD --> amod --> xxxx --> True --> False
# progression --> progression --> NOUN --> NN --> npadvmod --> xxxx --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# free --> free --> ADJ --> JJ --> amod --> xxxx --> True --> False
# survival --> survival --> NOUN --> NN --> conj --> xxxx --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# PFS --> PFS --> PROPN --> NNP --> appos --> XXX --> True --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# overall --> overall --> ADJ --> JJ --> amod --> xxxx --> True --> False
# survival --> survival --> NOUN --> NN --> conj --> xxxx --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# OS --> OS --> PROPN --> NNP --> appos --> XX --> True --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# , --> , --> PUNCT --> , --> punct --> , --> False --> False
# improved --> improve --> VERB --> VBN --> ROOT --> xxxx --> True --> False
# objective --> objective --> ADJ --> JJ --> amod --> xxxx --> True --> False
# response --> response --> NOUN --> NN --> compound --> xxxx --> True --> False
# rates --> rate --> NOUN --> NNS --> dobj --> xxxx --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# ORRs --> orr --> NOUN --> NNS --> appos --> XXXx --> True --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# preserved --> preserve --> VERB --> VBN --> amod --> xxxx --> True --> False
# health --> health --> NOUN --> NN --> npadvmod --> xxxx --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# related --> relate --> VERB --> VBN --> amod --> xxxx --> True --> False
# quality --> quality --> NOUN --> NN --> conj --> xxxx --> True --> False
# of --> of --> ADP --> IN --> prep --> xx --> True --> True
# life --> life --> NOUN --> NN --> pobj --> xxxx --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# HR --> HR --> PROPN --> NNP --> compound --> XX --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# QOL --> QOL --> PROPN --> NNP --> appos --> XXX --> True --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# to --> to --> ADP --> IN --> prep --> xx --> True --> True
# a --> a --> DET --> DT --> det --> x --> True --> True
# greater --> great --> ADJ --> JJR --> amod --> xxxx --> True --> False
# extent --> extent --> NOUN --> NN --> pobj --> xxxx --> True --> False
# than --> than --> ADP --> IN --> prep --> xxxx --> True --> True
# dabrafenib --> dabrafenib --> NOUN --> NN --> pobj --> xxxx --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# in --> in --> ADP --> IN --> prep --> xx --> True --> True
# the --> the --> DET --> DT --> det --> xxx --> True --> True
# double --> double --> ADJ --> JJ --> amod --> xxxx --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# blind --> blind --> ADJ --> JJ --> amod --> xxxx --> True --> False
# COMBI --> combi --> NOUN --> NN --> compound --> XXXX --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# d --> d --> ADJ --> JJ --> compound --> x --> True --> False
# study --> study --> NOUN --> NN --> pobj --> xxxx --> True --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# vemurafenib --> vemurafenib --> NOUN --> NN --> conj --> xxxx --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# in --> in --> ADP --> IN --> prep --> xx --> True --> True
# the --> the --> DET --> DT --> det --> xxx --> True --> True
# open --> open --> ADJ --> JJ --> amod --> xxxx --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# label --> label --> NOUN --> NN --> compound --> xxxx --> True --> False
# COMBI --> COMBI --> PROPN --> NNP --> compound --> XXXX --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# v --> v --> PROPN --> NNP --> compound --> x --> True --> False
# study --> study --> NOUN --> NN --> pobj --> xxxx --> True --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# in --> in --> ADP --> IN --> prep --> xx --> True --> True
# two --> two --> NUM --> CD --> nummod --> xxx --> True --> True
# large --> large --> ADJ --> JJ --> amod --> xxxx --> True --> False
# , --> , --> PUNCT --> , --> punct --> , --> False --> False
# randomized --> randomize --> VERB --> VBN --> conj --> xxxx --> True --> False
# , --> , --> PUNCT --> , --> punct --> , --> False --> False
# phase --> phase --> NOUN --> NN --> compound --> xxxx --> True --> False
# III --> iii --> NUM --> CD --> compound --> XXX --> True --> False
# studies --> study --> NOUN --> NNS --> pobj --> xxxx --> True --> False
# in --> in --> ADP --> IN --> prep --> xx --> True --> True
# treatment --> treatment --> NOUN --> NN --> pobj --> xxxx --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# naÃ¯ve --> naã¯ve --> NUM --> CD --> punct --> xxX¯xx --> False --> False
# patients --> patient --> NOUN --> NNS --> dobj --> xxxx --> True --> False
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# unresectable --> unresectable --> ADJ --> JJ --> amod --> xxxx --> True --> False
# or --> or --> CCONJ --> CC --> cc --> xx --> True --> True
# metastatic --> metastatic --> ADJ --> JJ --> conj --> xxxx --> True --> False
# melanoma --> melanoma --> NOUN --> NN --> pobj --> xxxx --> True --> False
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# BRAF --> BRAF --> PROPN --> NNP --> nmod --> XXXX --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# V600E --> V600E --> PROPN --> NNP --> nmod --> XdddX --> False --> False
# / --> / --> SYM --> SYM --> punct --> / --> False --> False
# K --> K --> PROPN --> NNP --> nmod --> X --> True --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# mutation --> mutation --> NOUN --> NN --> pobj --> xxxx --> True --> False
# . --> . --> PUNCT --> . --> punct --> . --> False --> False
# Limited --> limited --> ADJ --> JJ --> amod --> Xxxxx --> True --> False
# treatment --> treatment --> NOUN --> NN --> compound --> xxxx --> True --> False
# benefit --> benefit --> NOUN --> NN --> nsubjpass --> xxxx --> True --> False
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# the --> the --> DET --> DT --> det --> xxx --> True --> True
# combination --> combination --> NOUN --> NN --> pobj --> xxxx --> True --> False
# was --> be --> VERB --> VBD --> auxpass --> xxx --> True --> True
# also --> also --> ADV --> RB --> advmod --> xxxx --> True --> True
# seen --> see --> VERB --> VBN --> ROOT --> xxxx --> True --> False
# in --> in --> ADP --> IN --> prep --> xx --> True --> True
# patients --> patient --> NOUN --> NNS --> pobj --> xxxx --> True --> False
# who --> who --> PRON --> WP --> nsubj --> xxx --> True --> True
# had --> have --> VERB --> VBD --> aux --> xxx --> True --> True
# progressed --> progress --> VERB --> VBN --> relcl --> xxxx --> True --> False
# on --> on --> ADP --> IN --> prep --> xx --> True --> True
# prior --> prior --> ADJ --> JJ --> amod --> xxxx --> True --> False
# BRAF --> BRAF --> PROPN --> NNP --> compound --> XXXX --> True --> False
# inhibitor --> inhibitor --> NOUN --> NN --> compound --> xxxx --> True --> False
# therapy --> therapy --> NOUN --> NN --> pobj --> xxxx --> True --> False
# , --> , --> PUNCT --> , --> punct --> , --> False --> False
# as --> as --> ADP --> IN --> mark --> xx --> True --> True
# indicated --> indicate --> VERB --> VBN --> advcl --> xxxx --> True --> False
# by --> by --> ADP --> IN --> agent --> xx --> True --> True
# ORRs --> orr --> NOUN --> NNS --> pobj --> XXXx --> True --> False
# of --> of --> ADP --> IN --> prep --> xx --> True --> True
# â‰¤ --> â‰¤ --> SYM --> $ --> nmod --> x‰¤ --> False --> False
# 15Â --> 15â --> NUM --> CD --> nummod --> ddX --> False --> False
# % --> % --> NOUN --> NN --> pobj --> % --> False --> False
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# stable --> stable --> ADJ --> JJ --> amod --> xxxx --> True --> False
# disease --> disease --> NOUN --> NN --> conj --> xxxx --> True --> False
# in --> in --> ADP --> IN --> prep --> xx --> True --> True
# â‰¤ --> â‰¤ --> SYM --> $ --> pobj --> x‰¤ --> False --> False
# 50Â --> 50â --> NUM --> CD --> nummod --> ddX --> False --> False
# % --> % --> NOUN --> NN --> dobj --> % --> False --> False
# of --> of --> ADP --> IN --> prep --> xx --> True --> True
# patients --> patient --> NOUN --> NNS --> pobj --> xxxx --> True --> False
# in --> in --> ADP --> IN --> prep --> xx --> True --> True
# small --> small --> ADJ --> JJ --> amod --> xxxx --> True --> False
# phase --> phase --> NOUN --> NN --> nmod --> xxxx --> True --> False
# I --> -PRON- --> PRON --> PRP --> nmod --> X --> True --> True
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# II --> II --> PROPN --> NNP --> conj --> XX --> True --> False
# studies --> study --> NOUN --> NNS --> pobj --> xxxx --> True --> False
# . --> . --> PUNCT --> . --> punct --> . --> False --> False
# Combination --> combination --> NOUN --> NN --> compound --> Xxxxx --> True --> False
# therapy --> therapy --> NOUN --> NN --> nsubj --> xxxx --> True --> False
# did --> do --> VERB --> VBD --> aux --> xxx --> True --> True
# not --> not --> ADV --> RB --> neg --> xxx --> True --> True
# increase --> increase --> VERB --> VB --> ROOT --> xxxx --> True --> False
# overall --> overall --> ADJ --> JJ --> amod --> xxxx --> True --> False
# toxicity --> toxicity --> NOUN --> NN --> dobj --> xxxx --> True --> False
# relative --> relative --> ADJ --> JJ --> amod --> xxxx --> True --> False
# to --> to --> ADP --> IN --> prep --> xx --> True --> True
# dabrafenib --> dabrafenib --> NOUN --> NN --> pobj --> xxxx --> True --> False
# or --> or --> CCONJ --> CC --> cc --> xx --> True --> True
# vemurafenib --> vemurafenib --> NOUN --> NN --> conj --> xxxx --> True --> False
# monotherapy --> monotherapy --> NOUN --> NN --> advmod --> xxxx --> True --> False
# , --> , --> PUNCT --> , --> punct --> , --> False --> False
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# most --> most --> ADJ --> JJS --> amod --> xxxx --> True --> True
# adverse --> adverse --> ADJ --> JJ --> amod --> xxxx --> True --> False
# events --> event --> NOUN --> NNS --> pobj --> xxxx --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# AEs --> AEs --> PROPN --> NNP --> appos --> XXx --> True --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# mild --> mild --> ADJ --> JJ --> amod --> xxxx --> True --> False
# or --> or --> CCONJ --> CC --> cc --> xx --> True --> True
# moderate --> moderate --> ADJ --> JJ --> conj --> xxxx --> True --> False
# in --> in --> ADP --> IN --> prep --> xx --> True --> True
# severity --> severity --> NOUN --> NN --> pobj --> xxxx --> True --> False
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# generally --> generally --> ADV --> RB --> advmod --> xxxx --> True --> False
# manageable --> manageable --> ADJ --> JJ --> conj --> xxxx --> True --> False
# . --> . --> PUNCT --> . --> punct --> . --> False --> False
# Fewer --> few --> ADJ --> JJR --> amod --> Xxxxx --> True --> False
# skin --> skin --> NOUN --> NN --> npadvmod --> xxxx --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# related --> relate --> VERB --> VBN --> amod --> xxxx --> True --> False
# AEs --> ae --> NOUN --> NNS --> nsubjpass --> XXx --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# e.g. --> e.g. --> X --> FW --> amod --> x.x. --> False --> False
# cutaneous --> cutaneous --> ADJ --> JJ --> amod --> xxxx --> True --> False
# malignancies --> malignancy --> NOUN --> NNS --> appos --> xxxx --> True --> False
# , --> , --> PUNCT --> , --> punct --> , --> False --> False
# hyperkeratinosis --> hyperkeratinosis --> NOUN --> NN --> conj --> xxxx --> True --> False
# and --> and --> CCONJ --> CC --> cc --> xxx --> True --> True
# hand --> hand --> NOUN --> NN --> compound --> xxxx --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# foot --> foot --> NOUN --> NN --> compound --> xxxx --> True --> False
# syndrome --> syndrome --> NOUN --> NN --> conj --> xxxx --> True --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# were --> be --> VERB --> VBD --> auxpass --> xxxx --> True --> True
# reported --> report --> VERB --> VBN --> ROOT --> xxxx --> True --> False
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# combination --> combination --> NOUN --> NN --> compound --> xxxx --> True --> False
# therapy --> therapy --> NOUN --> NN --> pobj --> xxxx --> True --> False
# than --> than --> ADP --> IN --> prep --> xxxx --> True --> True
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# dabrafenib --> dabrafenib --> NOUN --> NN --> pobj --> xxxx --> True --> False
# or --> or --> CCONJ --> CC --> cc --> xx --> True --> True
# vemurafenib --> vemurafenib --> NOUN --> NN --> conj --> xxxx --> True --> False
# , --> , --> PUNCT --> , --> punct --> , --> False --> False
# probably --> probably --> ADV --> RB --> advmod --> xxxx --> True --> False
# because --> because --> ADP --> IN --> prep --> xxxx --> True --> True
# of --> of --> ADP --> IN --> pcomp --> xx --> True --> True
# reduced --> reduced --> ADJ --> JJ --> amod --> xxxx --> True --> False
# paradoxical --> paradoxical --> ADJ --> JJ --> amod --> xxxx --> True --> False
# activation --> activation --> NOUN --> NN --> pobj --> xxxx --> True --> False
# of --> of --> ADP --> IN --> prep --> xx --> True --> True
# the --> the --> DET --> DT --> det --> xxx --> True --> True
# MAPK --> MAPK --> PROPN --> NNP --> compound --> XXXX --> True --> False
# pathway --> pathway --> NOUN --> NN --> pobj --> xxxx --> True --> False
# . --> . --> PUNCT --> . --> punct --> . --> False --> False
# Thus --> thus --> ADV --> RB --> advmod --> Xxxx --> True --> True
# , --> , --> PUNCT --> , --> punct --> , --> False --> False
# dabrafenib --> dabrafenib --> NOUN --> NN --> nsubj --> xxxx --> True --> False
# plus --> plus --> CCONJ --> CC --> cc --> xxxx --> True --> False
# trametinib --> trametinib --> NOUN --> NN --> conj --> xxxx --> True --> False
# provides --> provide --> VERB --> VBZ --> ROOT --> xxxx --> True --> False
# an --> an --> DET --> DT --> det --> xx --> True --> True
# important --> important --> ADJ --> JJ --> amod --> xxxx --> True --> False
# treatment --> treatment --> NOUN --> NN --> compound --> xxxx --> True --> False
# option --> option --> NOUN --> NN --> dobj --> xxxx --> True --> False
# for --> for --> ADP --> IN --> prep --> xxx --> True --> True
# patients --> patient --> NOUN --> NNS --> pobj --> xxxx --> True --> False
# with --> with --> ADP --> IN --> prep --> xxxx --> True --> True
# BRAF --> BRAF --> PROPN --> NNP --> pobj --> XXXX --> True --> False
# ( --> ( --> PUNCT --> -LRB- --> punct --> ( --> False --> False
# V600 --> V600 --> PROPN --> NNP --> subtok --> Xddd --> False --> False
# ) --> ) --> PUNCT --> -RRB- --> punct --> ) --> False --> False
# mutation --> mutation --> NOUN --> NN --> npadvmod --> xxxx --> True --> False
# - --> - --> PUNCT --> HYPH --> punct --> - --> False --> False
# positive --> positive --> ADJ --> JJ --> amod --> xxxx --> True --> False
# unresectable --> unresectable --> ADJ --> JJ --> amod --> xxxx --> True --> False
# or --> or --> CCONJ --> CC --> cc --> xx --> True --> True
# metastatic --> metastatic --> ADJ --> JJ --> conj --> xxxx --> True --> False
# melanoma --> melanoma --> NOUN --> NN --> appos --> xxxx --> True --> False
# . --> . --> PUNCT --> . --> punct --> . --> False --> False
#
#  -->
#  --> SPACE --> _SP -->  -->
#  --> False --> False
#
# #---- Dependency Parsing ----#
#
# The BRAF inhibitor dabrafenib --> dabrafenib --> nsubjpass --> indicated
# (Tafinlar(Â® --> ® --> appos --> dabrafenib
# the MEK inhibitor trametinib --> trametinib --> conj --> dabrafenib
# Mekinist(Â® --> ® --> appos --> trametinib
# combination --> combination --> pobj --> in
# the treatment --> treatment --> pobj --> for
# patients --> patients --> pobj --> of
# unresectable or metastatic melanoma --> melanoma --> pobj --> with
# a BRAF (V600) mutation --> mutation --> pobj --> with
# This article --> article --> nsubj --> reviews
# the therapeutic efficacy --> efficacy --> dobj --> reviews
# tolerability --> tolerability --> conj --> efficacy
# combination treatment --> treatment --> pobj --> of
# dabrafenib --> dabrafenib --> pobj --> with
# trametinib --> trametinib --> conj --> dabrafenib
# this indication --> indication --> pobj --> in
# relevant pharmacological data --> data --> dobj --> summarizes
# Dabrafenib --> Dabrafenib --> nsubj --> improved
# trametinib --> trametinib --> conj --> Dabrafenib
# significantly prolonged progression-free survival --> survival --> conj --> Dabrafenib
# PFS --> PFS --> appos --> survival
# overall survival --> survival --> conj --> survival
# OS --> OS --> appos --> survival
# objective response rates --> rates --> dobj --> improved
# ORRs --> ORRs --> appos --> rates
# preserved health-related quality --> quality --> conj --> rates
# life --> life --> pobj --> of
# HR-QOL --> QOL --> appos --> quality
# a greater extent --> extent --> pobj --> to
# dabrafenib --> dabrafenib --> pobj --> than
# the double-blind COMBI-d study --> study --> pobj --> in
# vemurafenib --> vemurafenib --> conj --> extent
# the open-label COMBI-v study --> study --> pobj --> in
# two large, randomized, phase III studies --> studies --> pobj --> in
# treatment --> treatment --> pobj --> in
# patients --> patients --> dobj --> improved
# unresectable or metastatic melanoma --> melanoma --> pobj --> with
# BRAF (V600E/K) mutation --> mutation --> pobj --> with
# Limited treatment benefit --> benefit --> nsubjpass --> seen
# the combination --> combination --> pobj --> with
# patients --> patients --> pobj --> in
# who --> who --> nsubj --> progressed
# prior BRAF inhibitor therapy --> therapy --> pobj --> on
# ORRs --> ORRs --> pobj --> by
# â‰¤ 15Â % --> % --> pobj --> of
# stable disease --> disease --> conj --> ORRs
# 50Â % --> % --> dobj --> indicated
# patients --> patients --> pobj --> of
# small phase I and II studies --> studies --> pobj --> in
# Combination therapy --> therapy --> nsubj --> increase
# overall toxicity --> toxicity --> dobj --> increase
# dabrafenib --> dabrafenib --> pobj --> to
# vemurafenib --> vemurafenib --> conj --> dabrafenib
# most adverse events --> events --> pobj --> with
# AEs --> AEs --> appos --> events
# severity --> severity --> pobj --> in
# Fewer skin-related AEs --> AEs --> nsubjpass --> reported
# (e.g. cutaneous malignancies --> malignancies --> appos --> AEs
# hyperkeratinosis --> hyperkeratinosis --> conj --> malignancies
# hand-foot syndrome --> syndrome --> conj --> hyperkeratinosis
# combination therapy --> therapy --> pobj --> with
# dabrafenib --> dabrafenib --> pobj --> with
# vemurafenib --> vemurafenib --> conj --> dabrafenib
# reduced paradoxical activation --> activation --> pobj --> because
# the MAPK pathway --> pathway --> pobj --> of
# dabrafenib --> dabrafenib --> nsubj --> provides
# trametinib --> trametinib --> conj --> dabrafenib
# an important treatment option --> option --> dobj --> provides
# patients --> patients --> pobj --> for
# BRAF --> BRAF --> pobj --> with
# V600) mutation-positive unresectable or metastatic melanoma --> melanoma --> appos --> BRAF
#
# #---- Entity using Spacy ----#
#
# BRAF --> gene
# dabrafenib --> drug
# MEK --> protien
# trametinib --> drug
# melanoma --> diesease
# BRAF --> gene
# V600 --> varient
# trametinib --> drug
# Dabrafenib --> drug
# trametinib --> drug
# melanoma --> diesease
# BRAF --> gene
# V600E/K --> varient
# vemurafenib --> drug
# vemurafenib --> drug
# trametinib --> drug
# BRAF --> gene
# V600 --> varient
# melanoma --> diesease

# %%
nlp = spacy.load("en_core_web_lg")
for ent in nlp(doc1).ents:
    print(ent.text, "-->", ent.label_)
# Out:
# Tobias --> PERSON
# ’m --> PERSON
# 2018 --> DATE

# %% [markdown]
# # Playing with Displacy

# %%
from spacy import displacy

# %%
nlp = spacy.load("/home/ubuntu/Grakn/Spacy Play/spacy_en_core_web_lg")

# %%
doc = nlp(TEXTS)

# %% [markdown]
# ## Custome NER Model Output using Displacy

# %%
displacy.render(doc, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BRAF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">gene</span>
# </mark>
#  inhibitor
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     dabrafenib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">drug</span>
# </mark>
#  (Tafinlar(Â®)) and the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     MEK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">protien</span>
# </mark>
#  inhibitor
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     trametinib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">drug</span>
# </mark>
#  (Mekinist(Â®)) are indicated, as monotherapy or in combination with each other, for the treatment of patients with unresectable or metastatic
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     melanoma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">diesease</span>
# </mark>
#  with a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BRAF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">gene</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     V600
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">varient</span>
# </mark>
# ) mutation. </br>This article reviews the therapeutic efficacy and tolerability of combination treatment with dabrafenib and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     trametinib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">drug</span>
# </mark>
#  in this indication and summarizes relevant pharmacological data. </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Dabrafenib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">drug</span>
# </mark>
#  plus
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     trametinib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">drug</span>
# </mark>
#  significantly prolonged progression-free survival (PFS) and overall survival (OS), improved objective response rates (ORRs) and preserved health-related quality of life (HR-QOL) to a greater extent than dabrafenib (in the double-blind COMBI-d study) and vemurafenib (in the open-label COMBI-v study) in two large, randomized, phase III studies in treatment-naÃ¯ve patients with unresectable or metastatic
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     melanoma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">diesease</span>
# </mark>
#  with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BRAF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">gene</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     V600E/K
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">varient</span>
# </mark>
# ) mutation. Limited treatment benefit with the combination was also seen in patients who had progressed on prior BRAF inhibitor therapy, as indicated by ORRs of â‰¤ 15Â % and stable disease in â‰¤ 50Â % of patients in small phase I and II studies. Combination therapy did not increase overall toxicity relative to dabrafenib or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     vemurafenib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">drug</span>
# </mark>
#  monotherapy, with most adverse events (AEs) mild or moderate in severity and generally manageable. Fewer skin-related AEs (e.g. cutaneous malignancies, hyperkeratinosis and hand-foot syndrome) were reported with combination therapy than with dabrafenib or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     vemurafenib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">drug</span>
# </mark>
# , probably because of reduced paradoxical activation of the MAPK pathway. Thus, dabrafenib plus
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     trametinib
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">drug</span>
# </mark>
#  provides an important treatment option for patients with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-h

# %% [markdown]
# ## Pretrained NER Output

# %%
nlp = spacy.load("en_core_web_lg")

# %%
doc = nlp(TEXTS)

# %%
displacy.render(doc, style="ent")
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BRAF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  inhibitor dabrafenib (Tafinlar(Â®)) and the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     MEK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  inhibitor trametinib (Mekinist(Â®)) are indicated, as monotherapy or in combination with each other, for the treatment of patients with unresectable or metastatic melanoma with a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BRAF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (V600) mutation. </br>This article reviews the therapeutic efficacy and tolerability of combination treatment with dabrafenib and trametinib in this indication and summarizes relevant pharmacological data. </br>Dabrafenib plus trametinib significantly prolonged progression-free survival (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     PFS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) and overall survival (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     OS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), improved objective response rates (ORRs) and preserved health-related quality of life (HR-QOL) to a greater extent than dabrafenib (in the double-blind COMBI-d study) and vemurafenib (in the open-label COMBI-v study) in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  large, randomized, phase III studies in treatment-naÃ¯ve patients with unresectable or metastatic melanoma with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BRAF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (V600E/K) mutation. Limited treatment benefit with the combination was also seen in patients who had progressed on prior
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BRAF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  inhibitor therapy, as indicated by ORRs of â‰¤
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     15Â %
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  and stable disease in â‰¤
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     50Â %
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of patients in small phase I and II studies. Combination therapy did not increase overall toxicity relative to dabrafenib or vemurafenib monotherapy, with most adverse events (AEs) mild or moderate in severity and generally manageable. Fewer skin-related AEs (e.g. cutaneous malignancies, hyperkeratinosis and hand-foot syndrome) were reported with combination therapy than with dabrafenib or vemurafenib, probably because of reduced paradoxical activation of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     MAPK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  pathway. Thus, dabrafenib plus trametinib provides an important treatment option for patients with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BRAF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (V600) mutation-positive unresectable or metastatic melanoma.</div>

# %% [markdown]
# # Playing with Spacy - Entity Relation Extraction

# %%
#!/usr/bin/env python
# coding: utf8
"""A simple example of extracting relations between phrases and entities using
spaCy's named entity recognizer and the dependency parse. Here, we extract
money and currency values (entities labelled as MONEY) and then check the
dependency tree to find the noun phrase they are referring to – for example:
$9.4 million --> Net income.

Compatible with: spaCy v2.0.0+
Last tested with: v2.1.0
"""

from __future__ import unicode_literals, print_function

import plac
import spacy

# %%
TEXTS = [
    "Net income was $9.4 million compared to the prior year of $2.7 million.",
    "Revenue exceeded twelve billion dollars, with a loss of $1b.",
]

# %%
TEXTS = '''The BRAF inhibitor dabrafenib (Tafinlar(Â®)) and the MEK inhibitor trametinib (Mekinist(Â®)) are indicated, as monotherapy or in combination with each other, for the treatment of patients with unresectable or metastatic melanoma with a BRAF (V600) mutation. \nThis article reviews the therapeutic efficacy and tolerability of combination treatment with dabrafenib and trametinib in this indication and summarizes relevant pharmacological data. \nDabrafenib plus trametinib significantly prolonged progression-free survival (PFS) and overall survival (OS), improved objective response rates (ORRs) and preserved health-related quality of life (HR-QOL) to a greater extent than dabrafenib (in the double-blind COMBI-d study) and vemurafenib (in the open-label COMBI-v study) in two large, randomized, phase III studies in treatment-naÃ¯ve patients with unresectable or metastatic melanoma with BRAF (V600E/K) mutation. Limited treatment benefit with the combination was also seen in patients who had progressed on prior BRAF inhibitor therapy, as indicated by ORRs of â‰¤ 15Â % and stable disease in â‰¤ 50Â % of patients in small phase I and II studies. Combination therapy did not increase overall toxicity relative to dabrafenib or vemurafenib monotherapy, with most adverse events (AEs) mild or moderate in severity and generally manageable. Fewer skin-related AEs (e.g. cutaneous malignancies, hyperkeratinosis and hand-foot syndrome) were reported with combination therapy than with dabrafenib or vemurafenib, probably because of reduced paradoxical activation of the MAPK pathway. Thus, dabrafenib plus trametinib provides an important treatment option for patients with BRAF (V600) mutation-positive unresectable or metastatic melanoma.'''

# %%
@plac.annotations(model=("Model to load (needs parser and NER)", "positional", None, str))

def main(model="en_core_web_lg"): ##  "/home/ubuntu/Grakn/Spacy Play/spacy_en_core_web_lg"
    nlp = spacy.load(model)
    print("Loaded model '%s'" % model)
    print("Processing %d texts" % len(TEXTS))

    for text in TEXTS:
        doc = nlp(text)
        relations = extract_currency_relations(doc)
        for r1, r2 in relations:
            print("{:<10}\t{}\t{}".format(r1.text, r2.ent_type_, r2.text))


def filter_spans(spans):
    # Filter a sequence of spans so they don't contain overlaps
    get_sort_key = lambda span: (span.end - span.start, span.start)
    sorted_spans = sorted(spans, key=get_sort_key, reverse=True)
    result = []
    seen_tokens = set()
    for span in sorted_spans:
        if span.start not in seen_tokens and span.end - 1 not in seen_tokens:
            result.append(span)
            seen_tokens.update(range(span.start, span.end))
    return result


def extract_currency_relations(doc):
    # Merge entities and noun chunks into one token
    seen_tokens = set()
    spans = list(doc.ents) + list(doc.noun_chunks)
    spans = filter_spans(spans)
    with doc.retokenize() as retokenizer:
        for span in spans:
            retokenizer.merge(span)

    relations = []
    for money in filter(lambda w: w.ent_type_ =="MONEY" , doc): ##   "gene"                      
        if money.dep_ in ("attr", "dobj"):
            subject = [w for w in money.head.lefts if w.dep_ == "nsubj"]
            if subject:
                subject = subject[0]
                relations.append((subject, money))
        elif money.dep_ == "pobj" and money.head.dep_ == "prep":
            relations.append((money.head.head, money))
    return relations

# %%
main()

# %%
if __name__ == "__main__":
    plac.call(main)
